# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from yahoo_fin import stock_info as si
from collections import deque
import yfinance as yf
from pathlib import Path

import os
import numpy as np
import pandas as pd
import random

# %%
# set seed, so we can get the same results after rerunning several times
np.random.seed(314)
tf.random.set_seed(314)
random.seed(314)

# %%
def getTickerPriceData(tickers,period='3650d', interval='1d'):
    #Getting Ticker Price Data (Open,High,Close,etc)
    ticker_df = yf.download(tickers=tickers,period=period,interval=interval)
    return ticker_df

# %%
getTickerPriceData('SPY')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2006-09-26  132.500000  133.600006  132.399994  133.580002   99.726799
# 2006-09-27  133.490005  133.970001  133.270004  133.740005   99.846298
# 2006-09-28  133.740005  133.990005  133.279999  133.690002   99.808929
# 2006-09-29  133.800003  133.940002  133.479996  133.580002   99.726799
# 2006-10-02  133.539993  133.830002  132.949997  133.080002   99.353523
# ...                ...         ...         ...         ...         ...
# 2021-03-22  390.029999  394.070007  389.970001  392.589996  392.589996
# 2021-03-23  391.910004  393.459991  388.660004  389.500000  389.500000
# 2021-03-24  391.000000  392.750000  387.470001  387.519989  387.519989
# 2021-03-25  385.980011  390.549988  383.899994  389.700012  389.700012
# 2021-03-26  390.929993  396.410004  390.290009  395.980011  395.980011
#
#                Volume
# Date
# 2006-09-26   73962700
# 2006-09-27   82432200
# 2006-09-28   58597500
# 2006-09-29   47966600
# 2006-10-02   51687400
# ...               ...
# 2021-03-22   73778600
# 2021-03-23   90686600
# 2021-03-24   97588600
# 2021-03-25  116128600
# 2021-03-26  113023400
#
# [3650 rows x 6 columns]

# %%
def shuffle_in_unison(a, b):
    # shuffle two arrays in the same way
    state = np.random.get_state()
    np.random.shuffle(a)
    np.random.set_state(state)
    np.random.shuffle(b)

def load_data(ticker, n_steps=50, scale=True, shuffle=True, lookup_step=1, split_by_date=True,
                test_size=0.2, feature_columns=['Adj Close', 'Volume', 'Open', 'High', 'Low']):
    """
    Loads data from Yahoo Finance source, as well as scaling, shuffling, normalizing and splitting.
    Params:
        ticker (str/pd.DataFrame): the ticker you want to load, examples include AAPL, TESL, etc.
        n_steps (int): the historical sequence length (i.e window size) used to predict, default is 50
        scale (bool): whether to scale prices from 0 to 1, default is True
        shuffle (bool): whether to shuffle the dataset (both training & testing), default is True
        lookup_step (int): the future lookup step to predict, default is 1 (e.g next day)
        split_by_date (bool): whether we split the dataset into training/testing by date, setting it 
            to False will split datasets in a random way
        test_size (float): ratio for test data, default is 0.2 (20% testing data)
        feature_columns (list): the list of features to use to feed into the model, default is everything grabbed from yahoo_fin
    """
    # see if ticker is already a loaded stock from yahoo finance
    if isinstance(ticker, str):
        # load it from yfinance
        df = getTickerPriceData(ticker)
    elif isinstance(ticker, pd.DataFrame):
        # already loaded, use it directly
        df = ticker
    else:
        raise TypeError("ticker can be either a str or a `pd.DataFrame` instances")
    # this will contain all the elements we want to return from this function
    result = {}
    # we will also return the original dataframe itself
    result['df'] = df.copy()
    # make sure that the passed feature_columns exist in the dataframe
    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    # add date as a column
    if "date" not in df.columns:
        df["date"] = df.index
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['Adj Close'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns + ["date"]].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices that are not available in the dataset
    last_sequence = list([s[:len(feature_columns)] for s in sequences]) + list(last_sequence)
    last_sequence = np.array(last_sequence).astype(np.float32)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    if split_by_date:
        # split the dataset into training & testing sets by date (not randomly splitting)
        train_samples = int((1 - test_size) * len(X))
        result["X_train"] = X[:train_samples]
        result["y_train"] = y[:train_samples]
        result["X_test"]  = X[train_samples:]
        result["y_test"]  = y[train_samples:]
        if shuffle:
            # shuffle the datasets for training (if shuffle parameter is set)
            shuffle_in_unison(result["X_train"], result["y_train"])
            shuffle_in_unison(result["X_test"], result["y_test"])
    else:    
        # split the dataset randomly
        result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y, 
                                                                                test_size=test_size, shuffle=shuffle)
    # get the list of test set dates
    dates = result["X_test"][:, -1, -1]
    # retrieve test features from the original dataframe
    result["test_df"] = result["df"].loc[dates]
    # remove duplicated dates in the testing dataframe
    result["test_df"] = result["test_df"][~result["test_df"].index.duplicated(keep='first')]
    # remove dates from the training/testing sets & convert to float32
    result["X_train"] = result["X_train"][:, :, :len(feature_columns)].astype(np.float32)
    result["X_test"] = result["X_test"][:, :, :len(feature_columns)].astype(np.float32)
    return result

# %%
def create_model(sequence_length, n_features, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), batch_input_shape=(None, sequence_length, n_features)))
            else:
                model.add(cell(units, return_sequences=True, batch_input_shape=(None, sequence_length, n_features)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
import os
import time
from tensorflow.keras.layers import LSTM

# Window size or the sequence length
N_STEPS = 50
# Lookup step, 1 is the next day
LOOKUP_STEP = 10
# whether to scale feature columns & output price as well
SCALE = True
scale_str = f"sc-{int(SCALE)}"
# whether to shuffle the dataset
SHUFFLE = False
shuffle_str = f"sh-{int(SHUFFLE)}"
# whether to split the training/testing set by date
SPLIT_BY_DATE = True
split_by_date_str = f"sbd-{int(SPLIT_BY_DATE)}"
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.2
# features to use
FEATURE_COLUMNS = ["Adj Close", "Volume", "Open", "High", "Low"]
# date now
date_now = time.strftime("%Y-%m-%d")
### model parameters
N_LAYERS = 2
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 256
# 40% dropout
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = False
### training parameters
# mean absolute error loss
LOSS = "mae"
# huber loss
#LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 1000
# SPY ETF market
ticker = "SPY"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{shuffle_str}-{scale_str}-{split_by_date_str}-\
{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

# %%
# create these folders if they does not exist
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")

# %%
# load the data
data = load_data(ticker, N_STEPS, scale=SCALE, split_by_date=SPLIT_BY_DATE, 
                shuffle=SHUFFLE, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, 
                feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv(ticker_data_filename)
# construct the model
model = create_model(N_STEPS, len(FEATURE_COLUMNS), loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
# train the model and save the weights whenever we see 
# a new optimal model using ModelCheckpoint
history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/1000
# 45/45 [==============================] - 20s 357ms/step - loss: 0.0574 - mean_absolute_error: 0.0574 - val_loss: 0.0273 - val_mean_absolute_error: 0.0273
#
# Epoch 00001: val_loss improved from inf to 0.02734, saving model to results\2021-03-28_SPY-sh-0-sc-1-sbd-1-mae-adam-LSTM-seq-50-step-10-layers-2-units-256.h5
# Epoch 2/1000
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0220 - mean_absolute_error: 0.0220 - val_loss: 0.0684 - val_mean_absolute_error: 0.0684
#
# Epoch 00002: val_loss did not improve from 0.02734
# Epoch 3/1000
# 45/45 [==============================] - 13s 297ms/step - loss: 0.0232 - mean_absolute_error: 0.0232 - val_loss: 0.0307 - val_mean_absolute_error: 0.0307
#
# Epoch 00003: val_loss did not improve from 0.02734
# Epoch 4/1000
# 45/45 [==============================] - 14s 318ms/step - loss: 0.0201 - mean_absolute_error: 0.0201 - val_loss: 0.0363 - val_mean_absolute_error: 0.0363
#
# Epoch 00004: val_loss did not improve from 0.02734
# Epoch 5/1000
# 45/45 [==============================] - 14s 304ms/step - loss: 0.0188 - mean_absolute_error: 0.0188 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573
#
# Epoch 00005: val_loss did not improve from 0.02734
# Epoch 6/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.0475 - val_mean_absolute_error: 0.0475
#
# Epoch 00006: val_loss did not improve from 0.02734
# Epoch 7/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0184 - mean_absolute_error: 0.0184 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554
#
# Epoch 00007: val_loss did not improve from 0.02734
# Epoch 8/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0179 - mean_absolute_error: 0.0179 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532
#
# Epoch 00008: val_loss did not improve from 0.02734
# Epoch 9/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0184 - mean_absolute_error: 0.0184 - val_loss: 0.0258 - val_mean_absolute_error: 0.0258
#
# Epoch 00009: val_loss improved from 0.02734 to 0.02583, saving model to results\2021-03-28_SPY-sh-0-sc-1-sbd-1-mae-adam-LSTM-seq-50-step-10-layers-2-units-256.h5
# Epoch 10/1000
# 45/45 [==============================] - 14s 304ms/step - loss: 0.0175 - mean_absolute_error: 0.0175 - val_loss: 0.0274 - val_mean_absolute_error: 0.0274
#
# Epoch 00010: val_loss did not improve from 0.02583
# Epoch 11/1000
# 45/45 [==============================] - 13s 298ms/step - loss: 0.0178 - mean_absolute_error: 0.0178 - val_loss: 0.0402 - val_mean_absolute_error: 0.0402
#
# Epoch 00011: val_loss did not improve from 0.02583
# Epoch 12/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0179 - mean_absolute_error: 0.0179 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592
#
# Epoch 00012: val_loss did not improve from 0.02583
# Epoch 13/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0160 - mean_absolute_error: 0.0160 - val_loss: 0.0254 - val_mean_absolute_error: 0.0254
#
# Epoch 00013: val_loss improved from 0.02583 to 0.02544, saving model to results\2021-03-28_SPY-sh-0-sc-1-sbd-1-mae-adam-LSTM-seq-50-step-10-layers-2-units-256.h5
# Epoch 14/1000
# 45/45 [==============================] - 14s 309ms/step - loss: 0.0161 - mean_absolute_error: 0.0161 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520
#
# Epoch 00014: val_loss did not improve from 0.02544
# Epoch 15/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0176 - mean_absolute_error: 0.0176 - val_loss: 0.0266 - val_mean_absolute_error: 0.0266
#
# Epoch 00015: val_loss did not improve from 0.02544
# Epoch 16/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0189 - mean_absolute_error: 0.0189 - val_loss: 0.0316 - val_mean_absolute_error: 0.0316
#
# Epoch 00016: val_loss did not improve from 0.02544
# Epoch 17/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0166 - mean_absolute_error: 0.0166 - val_loss: 0.0330 - val_mean_absolute_error: 0.0330
#
# Epoch 00017: val_loss did not improve from 0.02544
# Epoch 18/1000
# 45/45 [==============================] - 14s 309ms/step - loss: 0.0152 - mean_absolute_error: 0.0152 - val_loss: 0.0356 - val_mean_absolute_error: 0.0356
#
# Epoch 00018: val_loss did not improve from 0.02544
# Epoch 19/1000
# 45/45 [==============================] - 14s 313ms/step - loss: 0.0151 - mean_absolute_error: 0.0151 - val_loss: 0.0497 - val_mean_absolute_error: 0.0497
#
# Epoch 00019: val_loss did not improve from 0.02544
# Epoch 20/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0158 - mean_absolute_error: 0.0158 - val_loss: 0.0278 - val_mean_absolute_error: 0.0278
#
# Epoch 00020: val_loss did not improve from 0.02544
# Epoch 21/1000
# 45/45 [==============================] - 14s 312ms/step - loss: 0.0150 - mean_absolute_error: 0.0150 - val_loss: 0.0275 - val_mean_absolute_error: 0.0275
#
# Epoch 00021: val_loss did not improve from 0.02544
# Epoch 22/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0159 - mean_absolute_error: 0.0159 - val_loss: 0.0442 - val_mean_absolute_error: 0.0442
#
# Epoch 00022: val_loss did not improve from 0.02544
# Epoch 23/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0143 - mean_absolute_error: 0.0143 - val_loss: 0.0344 - val_mean_absolute_error: 0.0344
#
# Epoch 00023: val_loss did not improve from 0.02544
# Epoch 24/1000
# 45/45 [==============================] - 14s 311ms/step - loss: 0.0140 - mean_absolute_error: 0.0140 - val_loss: 0.0316 - val_mean_absolute_error: 0.0316
#
# Epoch 00024: val_loss did not improve from 0.02544
# Epoch 25/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0154 - mean_absolute_error: 0.0154 - val_loss: 0.0324 - val_mean_absolute_error: 0.0324
#
# Epoch 00025: val_loss did not improve from 0.02544
# Epoch 26/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0151 - mean_absolute_error: 0.0151 - val_loss: 0.0252 - val_mean_absolute_error: 0.0252
#
# Epoch 00026: val_loss improved from 0.02544 to 0.02518, saving model to results\2021-03-28_SPY-sh-0-sc-1-sbd-1-mae-adam-LSTM-seq-50-step-10-layers-2-units-256.h5
# Epoch 27/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0147 - mean_absolute_error: 0.0147 - val_loss: 0.0322 - val_mean_absolute_error: 0.0322
#
# Epoch 00027: val_loss did not improve from 0.02518
# Epoch 28/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0150 - mean_absolute_error: 0.0150 - val_loss: 0.0351 - val_mean_absolute_error: 0.0351
#
# Epoch 00028: val_loss did not improve from 0.02518
# Epoch 29/1000
# 45/45 [==============================] - 14s 314ms/step - loss: 0.0154 - mean_absolute_error: 0.0154 - val_loss: 0.0299 - val_mean_absolute_error: 0.0299
#
# Epoch 00029: val_loss did not improve from 0.02518
# Epoch 30/1000
# 45/45 [==============================] - 15s 327ms/step - loss: 0.0136 - mean_absolute_error: 0.0136 - val_loss: 0.0278 - val_mean_absolute_error: 0.0278
#
# Epoch 00030: val_loss did not improve from 0.02518
# Epoch 31/1000
# 45/45 [==============================] - 15s 328ms/step - loss: 0.0143 - mean_absolute_error: 0.0143 - val_loss: 0.0251 - val_mean_absolute_error: 0.0251
#
# Epoch 00031: val_loss improved from 0.02518 to 0.02513, saving model to results\2021-03-28_SPY-sh-0-sc-1-sbd-1-mae-adam-LSTM-seq-50-step-10-layers-2-units-256.h5
# Epoch 32/1000
# 45/45 [==============================] - 15s 324ms/step - loss: 0.0139 - mean_absolute_error: 0.0139 - val_loss: 0.0369 - val_mean_absolute_error: 0.0369
#
# Epoch 00032: val_loss did not improve from 0.02513
# Epoch 33/1000
# 45/45 [==============================] - 15s 326ms/step - loss: 0.0136 - mean_absolute_error: 0.0136 - val_loss: 0.0467 - val_mean_absolute_error: 0.0467
#
# Epoch 00033: val_loss did not improve from 0.02513
# Epoch 34/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0139 - mean_absolute_error: 0.0139 - val_loss: 0.0338 - val_mean_absolute_error: 0.0338
#
# Epoch 00034: val_loss did not improve from 0.02513
# Epoch 35/1000
# 45/45 [==============================] - 14s 310ms/step - loss: 0.0130 - mean_absolute_error: 0.0130 - val_loss: 0.0335 - val_mean_absolute_error: 0.0335
#
# Epoch 00035: val_loss did not improve from 0.02513
# Epoch 36/1000
# 45/45 [==============================] - 14s 310ms/step - loss: 0.0138 - mean_absolute_error: 0.0138 - val_loss: 0.0347 - val_mean_absolute_error: 0.0347
#
# Epoch 00036: val_loss did not improve from 0.02513
# Epoch 37/1000
# 45/45 [==============================] - 15s 325ms/step - loss: 0.0141 - mean_absolute_error: 0.0141 - val_loss: 0.0380 - val_mean_absolute_error: 0.0380
#
# Epoch 00037: val_loss did not improve from 0.02513
# Epoch 38/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0146 - mean_absolute_error: 0.0146 - val_loss: 0.0681 - val_mean_absolute_error: 0.0681
#
# Epoch 00038: val_loss did not improve from 0.02513
# Epoch 39/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0141 - mean_absolute_error: 0.0141 - val_loss: 0.0382 - val_mean_absolute_error: 0.0382
#
# Epoch 00039: val_loss did not improve from 0.02513
# Epoch 40/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0289 - val_mean_absolute_error: 0.0289
#
# Epoch 00040: val_loss did not improve from 0.02513
# Epoch 41/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0341 - val_mean_absolute_error: 0.0341
#
# Epoch 00041: val_loss did not improve from 0.02513
# Epoch 42/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0144 - mean_absolute_error: 0.0144 - val_loss: 0.0402 - val_mean_absolute_error: 0.0402
#
# Epoch 00042: val_loss did not improve from 0.02513
# Epoch 43/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540
#
# Epoch 00043: val_loss did not improve from 0.02513
# Epoch 44/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0141 - mean_absolute_error: 0.0141 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296
#
# Epoch 00044: val_loss did not improve from 0.02513
# Epoch 45/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0141 - mean_absolute_error: 0.0141 - val_loss: 0.0272 - val_mean_absolute_error: 0.0272
#
# Epoch 00045: val_loss did not improve from 0.02513
# Epoch 46/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0162 - mean_absolute_error: 0.0162 - val_loss: 0.0394 - val_mean_absolute_error: 0.0394
#
# Epoch 00046: val_loss did not improve from 0.02513
# Epoch 47/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0301 - val_mean_absolute_error: 0.0301
#
# Epoch 00047: val_loss did not improve from 0.02513
# Epoch 48/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484
#
# Epoch 00048: val_loss did not improve from 0.02513
# Epoch 49/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.0402 - val_mean_absolute_error: 0.0402
#
# Epoch 00049: val_loss did not improve from 0.02513
# Epoch 50/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0135 - mean_absolute_error: 0.0135 - val_loss: 0.0288 - val_mean_absolute_error: 0.0288
#
# Epoch 00050: val_loss did not improve from 0.02513
# Epoch 51/1000
# 45/45 [==============================] - 15s 326ms/step - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.0298 - val_mean_absolute_error: 0.0298
#
# Epoch 00051: val_loss did not improve from 0.02513
# Epoch 52/1000
# 45/45 [==============================] - 15s 327ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0423 - val_mean_absolute_error: 0.0423
#
# Epoch 00052: val_loss did not improve from 0.02513
# Epoch 53/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0130 - mean_absolute_error: 0.0130 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408
#
# Epoch 00053: val_loss did not improve from 0.02513
# Epoch 54/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - val_loss: 0.0297 - val_mean_absolute_error: 0.0297
#
# Epoch 00054: val_loss did not improve from 0.02513
# Epoch 55/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - val_loss: 0.0423 - val_mean_absolute_error: 0.0423
#
# Epoch 00055: val_loss did not improve from 0.02513
# Epoch 56/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535
#
# Epoch 00056: val_loss did not improve from 0.02513
# Epoch 57/1000
# 45/45 [==============================] - 15s 328ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0296 - val_mean_absolute_error: 0.0296
#
# Epoch 00057: val_loss did not improve from 0.02513
# Epoch 58/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0463 - val_mean_absolute_error: 0.0463
#
# Epoch 00058: val_loss did not improve from 0.02513
# Epoch 59/1000
# 45/45 [==============================] - 14s 322ms/step - loss: 0.0136 - mean_absolute_error: 0.0136 - val_loss: 0.0397 - val_mean_absolute_error: 0.0397
#
# Epoch 00059: val_loss did not improve from 0.02513
# Epoch 60/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519
#
# Epoch 00060: val_loss did not improve from 0.02513
# Epoch 61/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0427 - val_mean_absolute_error: 0.0427
#
# Epoch 00061: val_loss did not improve from 0.02513
# Epoch 62/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0349 - val_mean_absolute_error: 0.0349
#
# Epoch 00062: val_loss did not improve from 0.02513
# Epoch 63/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0474 - val_mean_absolute_error: 0.0474
#
# Epoch 00063: val_loss did not improve from 0.02513
# Epoch 64/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - val_loss: 0.0389 - val_mean_absolute_error: 0.0389
#
# Epoch 00064: val_loss did not improve from 0.02513
# Epoch 65/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0472 - val_mean_absolute_error: 0.0472
#
# Epoch 00065: val_loss did not improve from 0.02513
# Epoch 66/1000
# 45/45 [==============================] - 15s 328ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0425 - val_mean_absolute_error: 0.0425
#
# Epoch 00066: val_loss did not improve from 0.02513
# Epoch 67/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0463 - val_mean_absolute_error: 0.0463
#
# Epoch 00067: val_loss did not improve from 0.02513
# Epoch 68/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0662 - val_mean_absolute_error: 0.0662
#
# Epoch 00068: val_loss did not improve from 0.02513
# Epoch 69/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0374 - val_mean_absolute_error: 0.0374
#
# Epoch 00069: val_loss did not improve from 0.02513
# Epoch 70/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0473 - val_mean_absolute_error: 0.0473
#
# Epoch 00070: val_loss did not improve from 0.02513
# Epoch 71/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584
#
# Epoch 00071: val_loss did not improve from 0.02513
# Epoch 72/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.0354 - val_mean_absolute_error: 0.0354
#
# Epoch 00072: val_loss did not improve from 0.02513
# Epoch 73/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0456 - val_mean_absolute_error: 0.0456
#
# Epoch 00073: val_loss did not improve from 0.02513
# Epoch 74/1000
# 45/45 [==============================] - 14s 316ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - val_loss: 0.0643 - val_mean_absolute_error: 0.0643
#
# Epoch 00074: val_loss did not improve from 0.02513
# Epoch 75/1000
# 45/45 [==============================] - 14s 318ms/step - loss: 0.0129 - mean_absolute_error: 0.0129 - val_loss: 0.0690 - val_mean_absolute_error: 0.0690
#
# Epoch 00075: val_loss did not improve from 0.02513
# Epoch 76/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0406 - val_mean_absolute_error: 0.0406
#
# Epoch 00076: val_loss did not improve from 0.02513
# Epoch 77/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0390 - val_mean_absolute_error: 0.0390
#
# Epoch 00077: val_loss did not improve from 0.02513
# Epoch 78/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0435 - val_mean_absolute_error: 0.0435
#
# Epoch 00078: val_loss did not improve from 0.02513
# Epoch 79/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0408 - val_mean_absolute_error: 0.0408
#
# Epoch 00079: val_loss did not improve from 0.02513
# Epoch 80/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582
#
# Epoch 00080: val_loss did not improve from 0.02513
# Epoch 81/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0467 - val_mean_absolute_error: 0.0467
#
# Epoch 00081: val_loss did not improve from 0.02513
# Epoch 82/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0651 - val_mean_absolute_error: 0.0651
#
# Epoch 00082: val_loss did not improve from 0.02513
# Epoch 83/1000
# 45/45 [==============================] - 15s 327ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0425 - val_mean_absolute_error: 0.0425
#
# Epoch 00083: val_loss did not improve from 0.02513
# Epoch 84/1000
# 45/45 [==============================] - 15s 339ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0636 - val_mean_absolute_error: 0.0636
#
# Epoch 00084: val_loss did not improve from 0.02513
# Epoch 85/1000
# 45/45 [==============================] - 16s 359ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0600 - val_mean_absolute_error: 0.0600
#
# Epoch 00085: val_loss did not improve from 0.02513
# Epoch 86/1000
# 45/45 [==============================] - 15s 342ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518
#
# Epoch 00086: val_loss did not improve from 0.02513
# Epoch 87/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591
#
# Epoch 00087: val_loss did not improve from 0.02513
# Epoch 88/1000
# 45/45 [==============================] - 15s 340ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0759 - val_mean_absolute_error: 0.0759
#
# Epoch 00088: val_loss did not improve from 0.02513
# Epoch 89/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484
#
# Epoch 00089: val_loss did not improve from 0.02513
# Epoch 90/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0479 - val_mean_absolute_error: 0.0479
#
# Epoch 00090: val_loss did not improve from 0.02513
# Epoch 91/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0633 - val_mean_absolute_error: 0.0633
#
# Epoch 00091: val_loss did not improve from 0.02513
# Epoch 92/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511
#
# Epoch 00092: val_loss did not improve from 0.02513
# Epoch 93/1000
# 45/45 [==============================] - 15s 337ms/step - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581
#
# Epoch 00093: val_loss did not improve from 0.02513
# Epoch 94/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0673 - val_mean_absolute_error: 0.0673
#
# Epoch 00094: val_loss did not improve from 0.02513
# Epoch 95/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0480 - val_mean_absolute_error: 0.0480
#
# Epoch 00095: val_loss did not improve from 0.02513
# Epoch 96/1000
# 45/45 [==============================] - 15s 337ms/step - loss: 0.0135 - mean_absolute_error: 0.0135 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701
#
# Epoch 00096: val_loss did not improve from 0.02513
# Epoch 97/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0666 - val_mean_absolute_error: 0.0666
#
# Epoch 00097: val_loss did not improve from 0.02513
# Epoch 98/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0681 - val_mean_absolute_error: 0.0681
#
# Epoch 00098: val_loss did not improve from 0.02513
# Epoch 99/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593
#
# Epoch 00099: val_loss did not improve from 0.02513
# Epoch 100/1000
# 45/45 [==============================] - 15s 345ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0642 - val_mean_absolute_error: 0.0642
#
# Epoch 00100: val_loss did not improve from 0.02513
# Epoch 101/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0648 - val_mean_absolute_error: 0.0648
#
# Epoch 00101: val_loss did not improve from 0.02513
# Epoch 102/1000
# 45/45 [==============================] - 15s 340ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0627 - val_mean_absolute_error: 0.0627
#
# Epoch 00102: val_loss did not improve from 0.02513
# Epoch 103/1000
# 45/45 [==============================] - 15s 339ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0812 - val_mean_absolute_error: 0.0812
#
# Epoch 00103: val_loss did not improve from 0.02513
# Epoch 104/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0773 - val_mean_absolute_error: 0.0773
#
# Epoch 00104: val_loss did not improve from 0.02513
# Epoch 105/1000
# 45/45 [==============================] - 15s 339ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0937 - val_mean_absolute_error: 0.0937
#
# Epoch 00105: val_loss did not improve from 0.02513
# Epoch 106/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
#
# Epoch 00106: val_loss did not improve from 0.02513
# Epoch 107/1000
# 45/45 [==============================] - 14s 323ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0667 - val_mean_absolute_error: 0.0667
#
# Epoch 00107: val_loss did not improve from 0.02513
# Epoch 108/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0817 - val_mean_absolute_error: 0.0817
#
# Epoch 00108: val_loss did not improve from 0.02513
# Epoch 109/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
#
# Epoch 00109: val_loss did not improve from 0.02513
# Epoch 110/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0719 - val_mean_absolute_error: 0.0719
#
# Epoch 00110: val_loss did not improve from 0.02513
# Epoch 111/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0672 - val_mean_absolute_error: 0.0672
#
# Epoch 00111: val_loss did not improve from 0.02513
# Epoch 112/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0732 - val_mean_absolute_error: 0.0732
#
# Epoch 00112: val_loss did not improve from 0.02513
# Epoch 113/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0753 - val_mean_absolute_error: 0.0753
#
# Epoch 00113: val_loss did not improve from 0.02513
# Epoch 114/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0810 - val_mean_absolute_error: 0.0810
#
# Epoch 00114: val_loss did not improve from 0.02513
# Epoch 115/1000
# 45/45 [==============================] - 14s 322ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0855 - val_mean_absolute_error: 0.0855
#
# Epoch 00115: val_loss did not improve from 0.02513
# Epoch 116/1000
# 45/45 [==============================] - 15s 341ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0993 - val_mean_absolute_error: 0.0993
#
# Epoch 00116: val_loss did not improve from 0.02513
# Epoch 117/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0821 - val_mean_absolute_error: 0.0821
#
# Epoch 00117: val_loss did not improve from 0.02513
# Epoch 118/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0814 - val_mean_absolute_error: 0.0814
#
# Epoch 00118: val_loss did not improve from 0.02513
# Epoch 119/1000
# 45/45 [==============================] - 15s 342ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0911 - val_mean_absolute_error: 0.0911
#
# Epoch 00119: val_loss did not improve from 0.02513
# Epoch 120/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0727 - val_mean_absolute_error: 0.0727
#
# Epoch 00120: val_loss did not improve from 0.02513
# Epoch 121/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.1063 - val_mean_absolute_error: 0.1063
#
# Epoch 00121: val_loss did not improve from 0.02513
# Epoch 122/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0912 - val_mean_absolute_error: 0.0912
#
# Epoch 00122: val_loss did not improve from 0.02513
# Epoch 123/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0773 - val_mean_absolute_error: 0.0773
#
# Epoch 00123: val_loss did not improve from 0.02513
# Epoch 124/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0835 - val_mean_absolute_error: 0.0835
#
# Epoch 00124: val_loss did not improve from 0.02513
# Epoch 125/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.0980 - val_mean_absolute_error: 0.0980
#
# Epoch 00125: val_loss did not improve from 0.02513
# Epoch 126/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.0883 - val_mean_absolute_error: 0.0883
#
# Epoch 00126: val_loss did not improve from 0.02513
# Epoch 127/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.0842 - val_mean_absolute_error: 0.0842
#
# Epoch 00127: val_loss did not improve from 0.02513
# Epoch 128/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0825 - val_mean_absolute_error: 0.0825
#
# Epoch 00128: val_loss did not improve from 0.02513
# Epoch 129/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
#
# Epoch 00129: val_loss did not improve from 0.02513
# Epoch 130/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0870 - val_mean_absolute_error: 0.0870
#
# Epoch 00130: val_loss did not improve from 0.02513
# Epoch 131/1000
# 45/45 [==============================] - 14s 323ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0835 - val_mean_absolute_error: 0.0835
#
# Epoch 00131: val_loss did not improve from 0.02513
# Epoch 132/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0798 - val_mean_absolute_error: 0.0798
#
# Epoch 00132: val_loss did not improve from 0.02513
# Epoch 133/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.0862 - val_mean_absolute_error: 0.0862
#
# Epoch 00133: val_loss did not improve from 0.02513
# Epoch 134/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.1057 - val_mean_absolute_error: 0.1057
#
# Epoch 00134: val_loss did not improve from 0.02513
# Epoch 135/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0136 - mean_absolute_error: 0.0136 - val_loss: 0.0923 - val_mean_absolute_error: 0.0923
#
# Epoch 00135: val_loss did not improve from 0.02513
# Epoch 136/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
#
# Epoch 00136: val_loss did not improve from 0.02513
# Epoch 137/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0894 - val_mean_absolute_error: 0.0894
#
# Epoch 00137: val_loss did not improve from 0.02513
# Epoch 138/1000
# 45/45 [==============================] - 15s 325ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0829 - val_mean_absolute_error: 0.0829
#
# Epoch 00138: val_loss did not improve from 0.02513
# Epoch 139/1000
# 45/45 [==============================] - 15s 324ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
#
# Epoch 00139: val_loss did not improve from 0.02513
# Epoch 140/1000
# 45/45 [==============================] - 15s 337ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.0876 - val_mean_absolute_error: 0.0876
#
# Epoch 00140: val_loss did not improve from 0.02513
# Epoch 141/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0892 - val_mean_absolute_error: 0.0892
#
# Epoch 00141: val_loss did not improve from 0.02513
# Epoch 142/1000
# 45/45 [==============================] - 15s 344ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.0758 - val_mean_absolute_error: 0.0758
#
# Epoch 00142: val_loss did not improve from 0.02513
# Epoch 143/1000
# 45/45 [==============================] - 16s 350ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0887 - val_mean_absolute_error: 0.0887
#
# Epoch 00143: val_loss did not improve from 0.02513
# Epoch 144/1000
# 45/45 [==============================] - 15s 340ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0932 - val_mean_absolute_error: 0.0932
#
# Epoch 00144: val_loss did not improve from 0.02513
# Epoch 145/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
#
# Epoch 00145: val_loss did not improve from 0.02513
# Epoch 146/1000
# 45/45 [==============================] - 15s 339ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0850 - val_mean_absolute_error: 0.0850
#
# Epoch 00146: val_loss did not improve from 0.02513
# Epoch 147/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
#
# Epoch 00147: val_loss did not improve from 0.02513
# Epoch 148/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0778 - val_mean_absolute_error: 0.0778
#
# Epoch 00148: val_loss did not improve from 0.02513
# Epoch 149/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
#
# Epoch 00149: val_loss did not improve from 0.02513
# Epoch 150/1000
# 45/45 [==============================] - 15s 339ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0918 - val_mean_absolute_error: 0.0918
#
# Epoch 00150: val_loss did not improve from 0.02513
# Epoch 151/1000
# 45/45 [==============================] - 15s 344ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.1062 - val_mean_absolute_error: 0.1062
#
# Epoch 00151: val_loss did not improve from 0.02513
# Epoch 152/1000
# 45/45 [==============================] - 15s 337ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.1083 - val_mean_absolute_error: 0.1083
#
# Epoch 00152: val_loss did not improve from 0.02513
# Epoch 153/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0910 - val_mean_absolute_error: 0.0910
#
# Epoch 00153: val_loss did not improve from 0.02513
# Epoch 154/1000
# 45/45 [==============================] - 15s 324ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - val_loss: 0.0971 - val_mean_absolute_error: 0.0971
#
# Epoch 00154: val_loss did not improve from 0.02513
# Epoch 155/1000
# 45/45 [==============================] - 15s 327ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
#
# Epoch 00155: val_loss did not improve from 0.02513
# Epoch 156/1000
# 45/45 [==============================] - 15s 337ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - val_loss: 0.0961 - val_mean_absolute_error: 0.0961
#
# Epoch 00156: val_loss did not improve from 0.02513
# Epoch 157/1000
# 45/45 [==============================] - 15s 337ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.0985 - val_mean_absolute_error: 0.0985
#
# Epoch 00157: val_loss did not improve from 0.02513
# Epoch 158/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.1019 - val_mean_absolute_error: 0.1019
#
# Epoch 00158: val_loss did not improve from 0.02513
# Epoch 159/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.1055 - val_mean_absolute_error: 0.1055
#
# Epoch 00159: val_loss did not improve from 0.02513
# Epoch 160/1000
# 45/45 [==============================] - 15s 339ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
#
# Epoch 00160: val_loss did not improve from 0.02513
# Epoch 161/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.1002 - val_mean_absolute_error: 0.1002
#
# Epoch 00161: val_loss did not improve from 0.02513
# Epoch 162/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0873 - val_mean_absolute_error: 0.0873
#
# Epoch 00162: val_loss did not improve from 0.02513
# Epoch 163/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.1045 - val_mean_absolute_error: 0.1045
#
# Epoch 00163: val_loss did not improve from 0.02513
# Epoch 164/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0900 - val_mean_absolute_error: 0.0900
#
# Epoch 00164: val_loss did not improve from 0.02513
# Epoch 165/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0126 - mean_absolute_error: 0.0126 - val_loss: 0.1030 - val_mean_absolute_error: 0.1030
#
# Epoch 00165: val_loss did not improve from 0.02513
# Epoch 166/1000
# 45/45 [==============================] - 15s 342ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0976 - val_mean_absolute_error: 0.0976
#
# Epoch 00166: val_loss did not improve from 0.02513
# Epoch 167/1000
# 45/45 [==============================] - 15s 323ms/step - loss: 0.0123 - mean_absolute_error: 0.0123 - val_loss: 0.1007 - val_mean_absolute_error: 0.1007
#
# Epoch 00167: val_loss did not improve from 0.02513
# Epoch 168/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.0899 - val_mean_absolute_error: 0.0899
#
# Epoch 00168: val_loss did not improve from 0.02513
# Epoch 169/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.1065 - val_mean_absolute_error: 0.1065
#
# Epoch 00169: val_loss did not improve from 0.02513
# Epoch 170/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.1004 - val_mean_absolute_error: 0.1004
#
# Epoch 00170: val_loss did not improve from 0.02513
# Epoch 171/1000
# 45/45 [==============================] - 14s 304ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.1128 - val_mean_absolute_error: 0.1128
#
# Epoch 00171: val_loss did not improve from 0.02513
# Epoch 172/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - val_loss: 0.1020 - val_mean_absolute_error: 0.1020
#
# Epoch 00172: val_loss did not improve from 0.02513
# Epoch 173/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.0971 - val_mean_absolute_error: 0.0971
#
# Epoch 00173: val_loss did not improve from 0.02513
# Epoch 174/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - val_loss: 0.0973 - val_mean_absolute_error: 0.0973
#
# Epoch 00174: val_loss did not improve from 0.02513
# Epoch 175/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.0815 - val_mean_absolute_error: 0.0815
#
# Epoch 00175: val_loss did not improve from 0.02513
# Epoch 176/1000
# 45/45 [==============================] - 15s 324ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.1038 - val_mean_absolute_error: 0.1038
#
# Epoch 00176: val_loss did not improve from 0.02513
# Epoch 177/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0971 - val_mean_absolute_error: 0.0971
#
# Epoch 00177: val_loss did not improve from 0.02513
# Epoch 178/1000
# 45/45 [==============================] - 14s 310ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - val_loss: 0.1140 - val_mean_absolute_error: 0.1140
#
# Epoch 00178: val_loss did not improve from 0.02513
# Epoch 179/1000
# 45/45 [==============================] - 13s 298ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - val_loss: 0.1007 - val_mean_absolute_error: 0.1007
#
# Epoch 00179: val_loss did not improve from 0.02513
# Epoch 180/1000
# 45/45 [==============================] - 14s 316ms/step - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.1003 - val_mean_absolute_error: 0.1003
#
# Epoch 00180: val_loss did not improve from 0.02513
# Epoch 181/1000
# 45/45 [==============================] - 14s 322ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.1089 - val_mean_absolute_error: 0.1089
#
# Epoch 00181: val_loss did not improve from 0.02513
# Epoch 182/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0997 - val_mean_absolute_error: 0.0997
#
# Epoch 00182: val_loss did not improve from 0.02513
# Epoch 183/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.1087 - val_mean_absolute_error: 0.1087
#
# Epoch 00183: val_loss did not improve from 0.02513
# Epoch 184/1000
# 45/45 [==============================] - 15s 325ms/step - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.1080 - val_mean_absolute_error: 0.1080
#
# Epoch 00184: val_loss did not improve from 0.02513
# Epoch 185/1000
# 45/45 [==============================] - 14s 318ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.1120 - val_mean_absolute_error: 0.1120
#
# Epoch 00185: val_loss did not improve from 0.02513
# Epoch 186/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - val_loss: 0.0970 - val_mean_absolute_error: 0.0970
#
# Epoch 00186: val_loss did not improve from 0.02513
# Epoch 187/1000
# 45/45 [==============================] - 13s 298ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - val_loss: 0.1197 - val_mean_absolute_error: 0.1197
#
# Epoch 00187: val_loss did not improve from 0.02513
# Epoch 188/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.1140 - val_mean_absolute_error: 0.1140
#
# Epoch 00188: val_loss did not improve from 0.02513
# Epoch 189/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - val_loss: 0.1044 - val_mean_absolute_error: 0.1044
#
# Epoch 00189: val_loss did not improve from 0.02513
# Epoch 190/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - val_loss: 0.1165 - val_mean_absolute_error: 0.1165
#
# Epoch 00190: val_loss did not improve from 0.02513
# Epoch 191/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - val_loss: 0.0975 - val_mean_absolute_error: 0.0975
#
# Epoch 00191: val_loss did not improve from 0.02513
# Epoch 192/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.1122 - val_mean_absolute_error: 0.1122
#
# Epoch 00192: val_loss did not improve from 0.02513
# Epoch 193/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - val_loss: 0.1051 - val_mean_absolute_error: 0.1051
#
# Epoch 00193: val_loss did not improve from 0.02513
# Epoch 194/1000
# 45/45 [==============================] - 14s 318ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.1053 - val_mean_absolute_error: 0.1053
#
# Epoch 00194: val_loss did not improve from 0.02513
# Epoch 195/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.1088 - val_mean_absolute_error: 0.1088
#
# Epoch 00195: val_loss did not improve from 0.02513
# Epoch 196/1000
# 45/45 [==============================] - 13s 298ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.1272 - val_mean_absolute_error: 0.1272
#
# Epoch 00196: val_loss did not improve from 0.02513
# Epoch 197/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0119 - mean_absolute_error: 0.0119 - val_loss: 0.1038 - val_mean_absolute_error: 0.1038
#
# Epoch 00197: val_loss did not improve from 0.02513
# Epoch 198/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
#
# Epoch 00198: val_loss did not improve from 0.02513
# Epoch 199/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.0941 - val_mean_absolute_error: 0.0941
#
# Epoch 00199: val_loss did not improve from 0.02513
# Epoch 200/1000
# 45/45 [==============================] - 14s 318ms/step - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.1040 - val_mean_absolute_error: 0.1040
#
# Epoch 00200: val_loss did not improve from 0.02513
# Epoch 201/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.1087 - val_mean_absolute_error: 0.1087
#
# Epoch 00201: val_loss did not improve from 0.02513
# Epoch 202/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.1138 - val_mean_absolute_error: 0.1138
#
# Epoch 00202: val_loss did not improve from 0.02513
# Epoch 203/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0115 - mean_absolute_error: 0.0115 - val_loss: 0.1104 - val_mean_absolute_error: 0.1104
#
# Epoch 00203: val_loss did not improve from 0.02513
# Epoch 204/1000
# 45/45 [==============================] - 13s 297ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.0914 - val_mean_absolute_error: 0.0914
#
# Epoch 00204: val_loss did not improve from 0.02513
# Epoch 205/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0128 - mean_absolute_error: 0.0128 - val_loss: 0.1093 - val_mean_absolute_error: 0.1093
#
# Epoch 00205: val_loss did not improve from 0.02513
# Epoch 206/1000
# 45/45 [==============================] - 14s 322ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - val_loss: 0.1145 - val_mean_absolute_error: 0.1145
#
# Epoch 00206: val_loss did not improve from 0.02513
# Epoch 207/1000
# 45/45 [==============================] - 15s 324ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - val_loss: 0.1075 - val_mean_absolute_error: 0.1075
#
# Epoch 00207: val_loss did not improve from 0.02513
# Epoch 208/1000
# 45/45 [==============================] - 15s 326ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.1036 - val_mean_absolute_error: 0.1036
#
# Epoch 00208: val_loss did not improve from 0.02513
# Epoch 209/1000
# 45/45 [==============================] - 14s 322ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.1090 - val_mean_absolute_error: 0.1090
#
# Epoch 00209: val_loss did not improve from 0.02513
# Epoch 210/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.1160 - val_mean_absolute_error: 0.1160
#
# Epoch 00210: val_loss did not improve from 0.02513
# Epoch 211/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0114 - mean_absolute_error: 0.0114 - val_loss: 0.1225 - val_mean_absolute_error: 0.1225
#
# Epoch 00211: val_loss did not improve from 0.02513
# Epoch 212/1000
# 45/45 [==============================] - 14s 323ms/step - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.1143 - val_mean_absolute_error: 0.1143
#
# Epoch 00212: val_loss did not improve from 0.02513
# Epoch 213/1000
# 45/45 [==============================] - 13s 301ms/step - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.1098 - val_mean_absolute_error: 0.1098
#
# Epoch 00213: val_loss did not improve from 0.02513
# Epoch 214/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0120 - mean_absolute_error: 0.0120 - val_loss: 0.1112 - val_mean_absolute_error: 0.1112
#
# Epoch 00214: val_loss did not improve from 0.02513
# Epoch 215/1000
# 45/45 [==============================] - 14s 318ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0962 - val_mean_absolute_error: 0.0962
#
# ...
#
# Epoch 00928: val_loss did not improve from 0.02513
# Epoch 929/1000
# 45/45 [==============================] - 15s 324ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.1693 - val_mean_absolute_error: 0.1693
#
# Epoch 00929: val_loss did not improve from 0.02513
# Epoch 930/1000
# 45/45 [==============================] - 14s 315ms/step - loss: 0.0098 - mean_absolute_error: 0.0098 - val_loss: 0.1745 - val_mean_absolute_error: 0.1745
#
# Epoch 00930: val_loss did not improve from 0.02513
# Epoch 931/1000
# 45/45 [==============================] - 14s 323ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1740 - val_mean_absolute_error: 0.1740
#
# Epoch 00931: val_loss did not improve from 0.02513
# Epoch 932/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1982 - val_mean_absolute_error: 0.1982
#
# Epoch 00932: val_loss did not improve from 0.02513
# Epoch 933/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - val_loss: 0.1856 - val_mean_absolute_error: 0.1856
#
# Epoch 00933: val_loss did not improve from 0.02513
# Epoch 934/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.1765 - val_mean_absolute_error: 0.1765
#
# Epoch 00934: val_loss did not improve from 0.02513
# Epoch 935/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.1569 - val_mean_absolute_error: 0.1569
#
# Epoch 00935: val_loss did not improve from 0.02513
# Epoch 936/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - val_loss: 0.1895 - val_mean_absolute_error: 0.1895
#
# Epoch 00936: val_loss did not improve from 0.02513
# Epoch 937/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.1674 - val_mean_absolute_error: 0.1674
#
# Epoch 00937: val_loss did not improve from 0.02513
# Epoch 938/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.1518 - val_mean_absolute_error: 0.1518
#
# Epoch 00938: val_loss did not improve from 0.02513
# Epoch 939/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
#
# Epoch 00939: val_loss did not improve from 0.02513
# Epoch 940/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1800 - val_mean_absolute_error: 0.1800
#
# Epoch 00940: val_loss did not improve from 0.02513
# Epoch 941/1000
# 45/45 [==============================] - 15s 345ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.1863 - val_mean_absolute_error: 0.1863
#
# Epoch 00941: val_loss did not improve from 0.02513
# Epoch 942/1000
# 45/45 [==============================] - 16s 346ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1784 - val_mean_absolute_error: 0.1784
#
# Epoch 00942: val_loss did not improve from 0.02513
# Epoch 943/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.1819 - val_mean_absolute_error: 0.1819
#
# Epoch 00943: val_loss did not improve from 0.02513
# Epoch 944/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
#
# Epoch 00944: val_loss did not improve from 0.02513
# Epoch 945/1000
# 45/45 [==============================] - 15s 327ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - val_loss: 0.1662 - val_mean_absolute_error: 0.1662
#
# Epoch 00945: val_loss did not improve from 0.02513
# Epoch 946/1000
# 45/45 [==============================] - 14s 316ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - val_loss: 0.1589 - val_mean_absolute_error: 0.1589
#
# Epoch 00946: val_loss did not improve from 0.02513
# Epoch 947/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.2042 - val_mean_absolute_error: 0.2042
#
# Epoch 00947: val_loss did not improve from 0.02513
# Epoch 948/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - val_loss: 0.1778 - val_mean_absolute_error: 0.1778
#
# Epoch 00948: val_loss did not improve from 0.02513
# Epoch 949/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.1874 - val_mean_absolute_error: 0.1874
#
# Epoch 00949: val_loss did not improve from 0.02513
# Epoch 950/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1685 - val_mean_absolute_error: 0.1685
#
# Epoch 00950: val_loss did not improve from 0.02513
# Epoch 951/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - val_loss: 0.1804 - val_mean_absolute_error: 0.1804
#
# Epoch 00951: val_loss did not improve from 0.02513
# Epoch 952/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - val_loss: 0.1637 - val_mean_absolute_error: 0.1637
#
# Epoch 00952: val_loss did not improve from 0.02513
# Epoch 953/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.1908 - val_mean_absolute_error: 0.1908
#
# Epoch 00953: val_loss did not improve from 0.02513
# Epoch 954/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.1947 - val_mean_absolute_error: 0.1947
#
# Epoch 00954: val_loss did not improve from 0.02513
# Epoch 955/1000
# 45/45 [==============================] - 14s 310ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.1740 - val_mean_absolute_error: 0.1740
#
# Epoch 00955: val_loss did not improve from 0.02513
# Epoch 956/1000
# 45/45 [==============================] - 15s 328ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1771 - val_mean_absolute_error: 0.1771
#
# Epoch 00956: val_loss did not improve from 0.02513
# Epoch 957/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.2162 - val_mean_absolute_error: 0.2162
#
# Epoch 00957: val_loss did not improve from 0.02513
# Epoch 958/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
#
# Epoch 00958: val_loss did not improve from 0.02513
# Epoch 959/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - val_loss: 0.1710 - val_mean_absolute_error: 0.1710
#
# Epoch 00959: val_loss did not improve from 0.02513
# Epoch 960/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.2211 - val_mean_absolute_error: 0.2211
#
# Epoch 00960: val_loss did not improve from 0.02513
# Epoch 961/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - val_loss: 0.1936 - val_mean_absolute_error: 0.1936
#
# Epoch 00961: val_loss did not improve from 0.02513
# Epoch 962/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1721 - val_mean_absolute_error: 0.1721
#
# Epoch 00962: val_loss did not improve from 0.02513
# Epoch 963/1000
# 45/45 [==============================] - 14s 312ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1653 - val_mean_absolute_error: 0.1653
#
# Epoch 00963: val_loss did not improve from 0.02513
# Epoch 964/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.1995 - val_mean_absolute_error: 0.1995
#
# Epoch 00964: val_loss did not improve from 0.02513
# Epoch 965/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - val_loss: 0.1784 - val_mean_absolute_error: 0.1784
#
# Epoch 00965: val_loss did not improve from 0.02513
# Epoch 966/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1706 - val_mean_absolute_error: 0.1706
#
# Epoch 00966: val_loss did not improve from 0.02513
# Epoch 967/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.1794 - val_mean_absolute_error: 0.1794
#
# Epoch 00967: val_loss did not improve from 0.02513
# Epoch 968/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - val_loss: 0.2018 - val_mean_absolute_error: 0.2018
#
# Epoch 00968: val_loss did not improve from 0.02513
# Epoch 969/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1958 - val_mean_absolute_error: 0.1958
#
# Epoch 00969: val_loss did not improve from 0.02513
# Epoch 970/1000
# 45/45 [==============================] - 15s 328ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - val_loss: 0.1538 - val_mean_absolute_error: 0.1538
#
# Epoch 00970: val_loss did not improve from 0.02513
# Epoch 971/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
#
# Epoch 00971: val_loss did not improve from 0.02513
# Epoch 972/1000
# 45/45 [==============================] - 15s 324ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - val_loss: 0.2106 - val_mean_absolute_error: 0.2106
#
# Epoch 00972: val_loss did not improve from 0.02513
# Epoch 973/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - val_loss: 0.2194 - val_mean_absolute_error: 0.2194
#
# Epoch 00973: val_loss did not improve from 0.02513
# Epoch 974/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - val_loss: 0.2229 - val_mean_absolute_error: 0.2229
#
# Epoch 00974: val_loss did not improve from 0.02513
# Epoch 975/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.2229 - val_mean_absolute_error: 0.2229
#
# Epoch 00975: val_loss did not improve from 0.02513
# Epoch 976/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.1989 - val_mean_absolute_error: 0.1989
#
# Epoch 00976: val_loss did not improve from 0.02513
# Epoch 977/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - val_loss: 0.1683 - val_mean_absolute_error: 0.1683
#
# Epoch 00977: val_loss did not improve from 0.02513
# Epoch 978/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.1585 - val_mean_absolute_error: 0.1585
#
# Epoch 00978: val_loss did not improve from 0.02513
# Epoch 979/1000
# 45/45 [==============================] - 14s 311ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.1624 - val_mean_absolute_error: 0.1624
#
# Epoch 00979: val_loss did not improve from 0.02513
# Epoch 980/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.1568 - val_mean_absolute_error: 0.1568
#
# Epoch 00980: val_loss did not improve from 0.02513
# Epoch 981/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.1638 - val_mean_absolute_error: 0.1638
#
# Epoch 00981: val_loss did not improve from 0.02513
# Epoch 982/1000
# 45/45 [==============================] - 15s 335ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.1924 - val_mean_absolute_error: 0.1924
#
# Epoch 00982: val_loss did not improve from 0.02513
# Epoch 983/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - val_loss: 0.2146 - val_mean_absolute_error: 0.2146
#
# Epoch 00983: val_loss did not improve from 0.02513
# Epoch 984/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.1893 - val_mean_absolute_error: 0.1893
#
# Epoch 00984: val_loss did not improve from 0.02513
# Epoch 985/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.2081 - val_mean_absolute_error: 0.2081
#
# Epoch 00985: val_loss did not improve from 0.02513
# Epoch 986/1000
# 45/45 [==============================] - 15s 328ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - val_loss: 0.1844 - val_mean_absolute_error: 0.1844
#
# Epoch 00986: val_loss did not improve from 0.02513
# Epoch 987/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.2165 - val_mean_absolute_error: 0.2165
#
# Epoch 00987: val_loss did not improve from 0.02513
# Epoch 988/1000
# 45/45 [==============================] - 14s 316ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - val_loss: 0.1865 - val_mean_absolute_error: 0.1865
#
# Epoch 00988: val_loss did not improve from 0.02513
# Epoch 989/1000
# 45/45 [==============================] - 15s 333ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.2380 - val_mean_absolute_error: 0.2380
#
# Epoch 00989: val_loss did not improve from 0.02513
# Epoch 990/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - val_loss: 0.2574 - val_mean_absolute_error: 0.2574
#
# Epoch 00990: val_loss did not improve from 0.02513
# Epoch 991/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.2103 - val_mean_absolute_error: 0.2103
#
# Epoch 00991: val_loss did not improve from 0.02513
# Epoch 992/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - val_loss: 0.2103 - val_mean_absolute_error: 0.2103
#
# Epoch 00992: val_loss did not improve from 0.02513
# Epoch 993/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.2651 - val_mean_absolute_error: 0.2651
#
# Epoch 00993: val_loss did not improve from 0.02513
# Epoch 994/1000
# 45/45 [==============================] - 15s 338ms/step - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.2207 - val_mean_absolute_error: 0.2207
#
# Epoch 00994: val_loss did not improve from 0.02513
# Epoch 995/1000
# 45/45 [==============================] - 15s 323ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - val_loss: 0.1720 - val_mean_absolute_error: 0.1720
#
# Epoch 00995: val_loss did not improve from 0.02513
# Epoch 996/1000
# 45/45 [==============================] - 14s 312ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - val_loss: 0.1722 - val_mean_absolute_error: 0.1722
#
# Epoch 00996: val_loss did not improve from 0.02513
# Epoch 997/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - val_loss: 0.1958 - val_mean_absolute_error: 0.1958
#
# Epoch 00997: val_loss did not improve from 0.02513
# Epoch 998/1000
# 45/45 [==============================] - 15s 332ms/step - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.2305 - val_mean_absolute_error: 0.2305
#
# Epoch 00998: val_loss did not improve from 0.02513
# Epoch 999/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - val_loss: 0.2537 - val_mean_absolute_error: 0.2537
#
# Epoch 00999: val_loss did not improve from 0.02513
# Epoch 1000/1000
# 45/45 [==============================] - 15s 330ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.2358 - val_mean_absolute_error: 0.2358
#
# Epoch 01000: val_loss did not improve from 0.02513

# %%
#Save the Model for import later

# Save model as JSON
model_1_day = model.to_json()

file_path = Path("model_3_10day.json")
with open(file_path, "w") as json_file:
    json_file.write(model_1_day)

# Save weights
model_3_10day_file_path = ("model_3_10day.h5")
model.save_weights("model_3_10day.h5")

# %%
import matplotlib.pyplot as plt

def plot_graph(test_df):
    """
    This function plots true close price along with predicted close price
    with blue and red colors respectively
    """
    plt.plot(test_df[f'true_adjclose_{LOOKUP_STEP}'], c='b')
    plt.plot(test_df[f'adjclose_{LOOKUP_STEP}'], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()

# %%
def get_final_df(model, data):
    """
    This function takes the `model` and `data` dict to 
    construct a final dataframe that includes the features along 
    with true and predicted prices of the testing dataset
    """
    # if predicted future price is higher than the current, 
    # then calculate the true future price minus the current price, to get the buy profit
    buy_profit  = lambda current, true_future, pred_future: true_future - current if pred_future > current else 0
    # if the predicted future price is lower than the current price,
    # then subtract the true future price from the current price
    sell_profit = lambda current, true_future, pred_future: current - true_future if pred_future < current else 0
    X_test = data["X_test"]
    y_test = data["y_test"]
    # perform prediction and get prices
    y_pred = model.predict(X_test)
    if SCALE:
        y_test = np.squeeze(data["column_scaler"]["Adj Close"].inverse_transform(np.expand_dims(y_test, axis=0)))
        y_pred = np.squeeze(data["column_scaler"]["Adj Close"].inverse_transform(y_pred))
    test_df = data["test_df"]
    # add predicted future prices to the dataframe
    test_df[f"adjclose_{LOOKUP_STEP}"] = y_pred
    # add true future prices to the dataframe
    test_df[f"true_adjclose_{LOOKUP_STEP}"] = y_test
    # sort the dataframe by date
    test_df.sort_index(inplace=True)
    final_df = test_df
    # add the buy profit column
    final_df["buy_profit"] = list(map(buy_profit, 
                                    final_df["Adj Close"], 
                                    final_df[f"adjclose_{LOOKUP_STEP}"], 
                                    final_df[f"true_adjclose_{LOOKUP_STEP}"])
                                    # since we don't have profit for last sequence, add 0's
                                    )
    # add the sell profit column
    final_df["sell_profit"] = list(map(sell_profit, 
                                    final_df["Adj Close"], 
                                    final_df[f"adjclose_{LOOKUP_STEP}"], 
                                    final_df[f"true_adjclose_{LOOKUP_STEP}"])
                                    # since we don't have profit for last sequence, add 0's
                                    )
    return final_df

# %%
def predict(model, data):
    # retrieve the last sequence from data
    last_sequence = data["last_sequence"][-N_STEPS:]
    # expand dimension
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    if SCALE:
        predicted_price = data["column_scaler"]["Adj Close"].inverse_transform(prediction)[0][0]
    else:
        predicted_price = prediction[0][0]# load optimal model weights from results folder
    model_path = os.path.join("results", model_name) + ".h5"
    model.load_weights(model_path)
    return predicted_price

# %%
# load optimal model weights from results folder
model_path = os.path.join("results", model_name) + ".h5"
model.load_weights(model_path)

# %%
# evaluate the model
loss, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
if SCALE:
    mean_absolute_error = data["column_scaler"]["Adj Close"].inverse_transform([[mae]])[0][0]
else:
    mean_absolute_error = mae

# %%
# predict the future price
final_df = get_final_df(model, data)

# predict the future price
future_price = predict(model, data)

final_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-04  261.519989  266.790009  261.149994  266.019989  251.695648
# 2018-05-07  266.890015  268.019989  266.109985  266.920013  252.547226
# 2018-05-08  266.500000  267.329987  265.149994  266.920013  252.547226
# 2018-05-09  267.679993  269.869995  267.089996  269.500000  254.988251
# 2018-05-10  270.339996  272.390015  270.220001  272.019989  257.372559
# ...                ...         ...         ...         ...         ...
# 2021-03-08  384.660004  387.679993  381.420013  381.720001  380.473846
# 2021-03-09  385.850006  389.910004  385.309998  387.170013  385.906067
# 2021-03-10  389.690002  391.399994  388.170013  389.579987  388.308197
# 2021-03-11  392.230011  395.649994  391.739990  393.529999  392.245300
# 2021-03-12  392.070007  394.209991  391.200012  394.059998  392.773560
#
#                Volume  adjclose_10  true_adjclose_10  buy_profit  sell_profit
# Date
# 2018-05-04   91222100   256.495728        256.719727    4.800079     0.000000
# 2018-05-07   55304900   257.120911        258.649841    4.573685     0.000000
# 2018-05-08   67499200   257.645996        257.930786    5.098770     0.000000
# 2018-05-09   59666100   258.414398        258.640411    3.426147     0.000000
# 2018-05-10   72063900   259.327820        258.110626    1.955261     0.000000
# ...               ...          ...               ...         ...          ...
# 2021-03-08  122957100   380.742065        392.589996    0.268219     0.000000
# 2021-03-09  113457800   380.882416        389.500000   -5.023651     0.000000
# 2021-03-10  109660800   381.417053        387.519989    0.000000     6.891144
# 2021-03-11   86027400   382.540680        389.700012    0.000000     9.704620
# 2021-03-12   64608100   383.885529        395.980011   -8.888031     0.000000
#
# [719 rows x 10 columns]

# %%
# we calculate the accuracy by counting the number of positive profits
accuracy_score = (len(final_df[final_df['sell_profit'] > 0]) + len(final_df[final_df['buy_profit'] > 0])) / len(final_df)
# calculating total buy & sell profit
total_buy_profit  = final_df["buy_profit"].sum()
total_sell_profit = final_df["sell_profit"].sum()
# total profit by adding sell & buy together
total_profit = total_buy_profit + total_sell_profit
# dividing total profit by number of testing samples (number of trades)
profit_per_trade = total_profit / len(final_df)

# %%
# printing metrics
print(f"Future price after {LOOKUP_STEP} days is {future_price:.2f}$")
print(f"{LOSS} loss:", loss)
print("Mean Absolute Error:", mean_absolute_error)
print("Accuracy score:", accuracy_score)
print("Total buy profit:", total_buy_profit)
print("Total sell profit:", total_sell_profit)
print("Total profit:", total_profit)
print("Profit per trade:", profit_per_trade)
# Out:
# Future price after 10 days is 388.00$
# mae loss: 0.025129185989499092
# Mean Absolute Error: 61.939736684645126
# Accuracy score: 0.6216968011126565
# Total buy profit: 1860.7505950927734
# Total sell profit: -968.3709106445312
# Total profit: 892.3796844482422
# Profit per trade: 1.2411400340031185

# %%
# printing metrics
print(f"This model predicts the Future price after {LOOKUP_STEP} days will be {future_price:.2f}$")
# plot true/pred prices graph
plot_graph(final_df)
# Out:
# This model predicts the Future price after 10 days will be 388.00$
