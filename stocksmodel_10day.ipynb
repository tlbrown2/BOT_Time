# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from yahoo_fin import stock_info as si
from collections import deque
import yfinance as yf
from pathlib import Path

import os
import numpy as np
import pandas as pd
import random

# %%
# set seed, so we can get the same results after rerunning several times
np.random.seed(314)
tf.random.set_seed(314)
random.seed(314)

# %%
def getTickerPriceData(tickers,period='3650d', interval='1d'):
    #Getting Ticker Price Data (Open,High,Close,etc)
    ticker_df = yf.download(tickers=tickers,period=period,interval=interval)
    return ticker_df

# %%
getTickerPriceData(['TSLA'])
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...                ...         ...         ...         ...         ...
# 2021-03-23  675.770020  677.799988  657.510010  662.159973  662.159973
# 2021-03-24  667.909973  668.020020  630.109985  630.270020  630.270020
# 2021-03-25  613.000000  645.500000  609.500000  640.390015  640.390015
# 2021-03-26  641.869995  643.820007  599.890015  618.710022  618.710022
# 2021-03-29  615.640015  616.450012  596.020020  611.289978  611.289978
#
#               Volume
# Date
# 2010-06-29  93831500
# 2010-06-30  85935500
# 2010-07-01  41094000
# 2010-07-02  25699000
# 2010-07-06  34334500
# ...              ...
# 2021-03-23  30491900
# 2021-03-24  33795200
# 2021-03-25  39224900
# 2021-03-26  33778400
# 2021-03-29  28636985
#
# [2706 rows x 6 columns]

# %%
def shuffle_in_unison(a, b):
    # shuffle two arrays in the same way
    state = np.random.get_state()
    np.random.shuffle(a)
    np.random.set_state(state)
    np.random.shuffle(b)

def load_data(ticker, n_steps=50, scale=True, shuffle=True, lookup_step=1, split_by_date=True,
                test_size=0.2, feature_columns=['Adj Close', 'Volume', 'Open', 'High', 'Low']):
    """
    Loads data from Yahoo Finance source, as well as scaling, shuffling, normalizing and splitting.
    Params:
        ticker (str/pd.DataFrame): the ticker you want to load, examples include AAPL, TESL, etc.
        n_steps (int): the historical sequence length (i.e window size) used to predict, default is 50
        scale (bool): whether to scale prices from 0 to 1, default is True
        shuffle (bool): whether to shuffle the dataset (both training & testing), default is True
        lookup_step (int): the future lookup step to predict, default is 1 (e.g next day)
        split_by_date (bool): whether we split the dataset into training/testing by date, setting it 
            to False will split datasets in a random way
        test_size (float): ratio for test data, default is 0.2 (20% testing data)
        feature_columns (list): the list of features to use to feed into the model, default is everything grabbed from yahoo_fin
    """
    # see if ticker is already a loaded stock from yahoo finance
    if isinstance(ticker, str):
        # load it from yfinance
        df = getTickerPriceData(ticker)
    elif isinstance(ticker, pd.DataFrame):
        # already loaded, use it directly
        df = ticker
    else:
        raise TypeError("ticker can be either a str or a `pd.DataFrame` instances")
    # this will contain all the elements we want to return from this function
    result = {}
    # we will also return the original dataframe itself
    result['df'] = df.copy()
    # make sure that the passed feature_columns exist in the dataframe
    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    # add date as a column
    if "date" not in df.columns:
        df["date"] = df.index
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['Adj Close'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns + ["date"]].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices that are not available in the dataset
    last_sequence = list([s[:len(feature_columns)] for s in sequences]) + list(last_sequence)
    last_sequence = np.array(last_sequence).astype(np.float32)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    if split_by_date:
        # split the dataset into training & testing sets by date (not randomly splitting)
        train_samples = int((1 - test_size) * len(X))
        result["X_train"] = X[:train_samples]
        result["y_train"] = y[:train_samples]
        result["X_test"]  = X[train_samples:]
        result["y_test"]  = y[train_samples:]
        if shuffle:
            # shuffle the datasets for training (if shuffle parameter is set)
            shuffle_in_unison(result["X_train"], result["y_train"])
            shuffle_in_unison(result["X_test"], result["y_test"])
    else:    
        # split the dataset randomly
        result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y, 
                                                                                test_size=test_size, shuffle=shuffle)
    # get the list of test set dates
    dates = result["X_test"][:, -1, -1]
    # retrieve test features from the original dataframe
    result["test_df"] = result["df"].loc[dates]
    # remove duplicated dates in the testing dataframe
    result["test_df"] = result["test_df"][~result["test_df"].index.duplicated(keep='first')]
    # remove dates from the training/testing sets & convert to float32
    result["X_train"] = result["X_train"][:, :, :len(feature_columns)].astype(np.float32)
    result["X_test"] = result["X_test"][:, :, :len(feature_columns)].astype(np.float32)
    return result

# %%
def create_model(sequence_length, n_features, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), batch_input_shape=(None, sequence_length, n_features)))
            else:
                model.add(cell(units, return_sequences=True, batch_input_shape=(None, sequence_length, n_features)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
import os
import time
from tensorflow.keras.layers import LSTM

# Window size or the sequence length
N_STEPS = 50
# Lookup step, 1 is the next day
LOOKUP_STEP = 10
# whether to scale feature columns & output price as well
SCALE = True
scale_str = f"sc-{int(SCALE)}"
# whether to shuffle the dataset
SHUFFLE = False
shuffle_str = f"sh-{int(SHUFFLE)}"
# whether to split the training/testing set by date
SPLIT_BY_DATE = True
split_by_date_str = f"sbd-{int(SPLIT_BY_DATE)}"
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.2
# features to use
FEATURE_COLUMNS = ["Adj Close", "Volume", "Open", "High", "Low"]
# date now
date_now = time.strftime("%Y-%m-%d")
### model parameters
N_LAYERS = 2
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 256
# 40% dropout
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = False
### training parameters
# mean absolute error loss
LOSS = "mae"
# huber loss
#LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 1000
# Apple Stock 
ticker = "TSLA"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{shuffle_str}-{scale_str}-{split_by_date_str}-\
{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

# %%
# create these folders if they does not exist
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")

# %%
# load the data
data = load_data(ticker, N_STEPS, scale=SCALE, split_by_date=SPLIT_BY_DATE, 
                shuffle=SHUFFLE, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, 
                feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv(ticker_data_filename)
# construct the model
model = create_model(N_STEPS, len(FEATURE_COLUMNS), loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
# train the model and save the weights whenever we see 
# a new optimal model using ModelCheckpoint
history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/1000
# 34/34 [==============================] - 25s 599ms/step - loss: 0.0189 - mean_absolute_error: 0.0189 - val_loss: 0.0414 - val_mean_absolute_error: 0.0414
#
# Epoch 00001: val_loss improved from inf to 0.04136, saving model to results\2021-03-29_TSLA-sh-0-sc-1-sbd-1-mae-adam-LSTM-seq-50-step-10-layers-2-units-256.h5
# Epoch 2/1000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.0419 - val_mean_absolute_error: 0.0419
#
# Epoch 00002: val_loss did not improve from 0.04136
# Epoch 3/1000
# 34/34 [==============================] - 16s 459ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616
#
# Epoch 00003: val_loss did not improve from 0.04136
# Epoch 4/1000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.0473 - val_mean_absolute_error: 0.0473
#
# Epoch 00004: val_loss did not improve from 0.04136
# Epoch 5/1000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625
#
# Epoch 00005: val_loss did not improve from 0.04136
# Epoch 6/1000
# 34/34 [==============================] - 15s 432ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - val_loss: 0.0618 - val_mean_absolute_error: 0.0618
#
# Epoch 00006: val_loss did not improve from 0.04136
# Epoch 7/1000
# 34/34 [==============================] - 14s 423ms/step - loss: 0.0048 - mean_absolute_error: 0.0048 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510
#
# Epoch 00007: val_loss did not improve from 0.04136
# Epoch 8/1000
# 34/34 [==============================] - 14s 423ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - val_loss: 0.0778 - val_mean_absolute_error: 0.0778
#
# Epoch 00008: val_loss did not improve from 0.04136
# Epoch 9/1000
# 34/34 [==============================] - 15s 437ms/step - loss: 0.0046 - mean_absolute_error: 0.0046 - val_loss: 0.0683 - val_mean_absolute_error: 0.0683
#
# Epoch 00009: val_loss did not improve from 0.04136
# Epoch 10/1000
# 34/34 [==============================] - 15s 437ms/step - loss: 0.0057 - mean_absolute_error: 0.0057 - val_loss: 0.0692 - val_mean_absolute_error: 0.0692
#
# Epoch 00010: val_loss did not improve from 0.04136
# Epoch 11/1000
# 34/34 [==============================] - 15s 435ms/step - loss: 0.0044 - mean_absolute_error: 0.0044 - val_loss: 0.0805 - val_mean_absolute_error: 0.0805
#
# Epoch 00011: val_loss did not improve from 0.04136
# Epoch 12/1000
# 34/34 [==============================] - 15s 433ms/step - loss: 0.0043 - mean_absolute_error: 0.0043 - val_loss: 0.0814 - val_mean_absolute_error: 0.0814
#
# Epoch 00012: val_loss did not improve from 0.04136
# Epoch 13/1000
# 34/34 [==============================] - 15s 431ms/step - loss: 0.0045 - mean_absolute_error: 0.0045 - val_loss: 0.0776 - val_mean_absolute_error: 0.0776
#
# Epoch 00013: val_loss did not improve from 0.04136
# Epoch 14/1000
# 34/34 [==============================] - 15s 428ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - val_loss: 0.0940 - val_mean_absolute_error: 0.0940
#
# Epoch 00014: val_loss did not improve from 0.04136
# Epoch 15/1000
# 34/34 [==============================] - 14s 426ms/step - loss: 0.0044 - mean_absolute_error: 0.0044 - val_loss: 0.0919 - val_mean_absolute_error: 0.0919
#
# Epoch 00015: val_loss did not improve from 0.04136
# Epoch 16/1000
# 34/34 [==============================] - 14s 427ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - val_loss: 0.0795 - val_mean_absolute_error: 0.0795
#
# Epoch 00016: val_loss did not improve from 0.04136
# Epoch 17/1000
# 34/34 [==============================] - 15s 431ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - val_loss: 0.0845 - val_mean_absolute_error: 0.0845
#
# Epoch 00017: val_loss did not improve from 0.04136
# Epoch 18/1000
# 34/34 [==============================] - 15s 430ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
#
# Epoch 00018: val_loss did not improve from 0.04136
# Epoch 19/1000
# 34/34 [==============================] - 15s 454ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.0955 - val_mean_absolute_error: 0.0955
#
# Epoch 00019: val_loss did not improve from 0.04136
# Epoch 20/1000
# 34/34 [==============================] - 14s 427ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.0916 - val_mean_absolute_error: 0.0916
#
# Epoch 00020: val_loss did not improve from 0.04136
# Epoch 21/1000
# 34/34 [==============================] - 15s 427ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.0909 - val_mean_absolute_error: 0.0909
#
# Epoch 00021: val_loss did not improve from 0.04136
# Epoch 22/1000
# 34/34 [==============================] - 14s 426ms/step - loss: 0.0046 - mean_absolute_error: 0.0046 - val_loss: 0.0919 - val_mean_absolute_error: 0.0919
#
# Epoch 00022: val_loss did not improve from 0.04136
# Epoch 23/1000
# 34/34 [==============================] - 15s 428ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
#
# Epoch 00023: val_loss did not improve from 0.04136
# Epoch 24/1000
# 34/34 [==============================] - 15s 429ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
#
# Epoch 00024: val_loss did not improve from 0.04136
# Epoch 25/1000
# 34/34 [==============================] - 15s 430ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.0968 - val_mean_absolute_error: 0.0968
#
# Epoch 00025: val_loss did not improve from 0.04136
# Epoch 26/1000
# 34/34 [==============================] - 15s 427ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1034 - val_mean_absolute_error: 0.1034
#
# Epoch 00026: val_loss did not improve from 0.04136
# Epoch 27/1000
# 34/34 [==============================] - 14s 428ms/step - loss: 0.0043 - mean_absolute_error: 0.0043 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
#
# Epoch 00027: val_loss did not improve from 0.04136
# Epoch 28/1000
# 34/34 [==============================] - 15s 433ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.1100 - val_mean_absolute_error: 0.1100
#
# Epoch 00028: val_loss did not improve from 0.04136
# Epoch 29/1000
# 34/34 [==============================] - 15s 430ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - val_loss: 0.1108 - val_mean_absolute_error: 0.1108
#
# Epoch 00029: val_loss did not improve from 0.04136
# Epoch 30/1000
# 34/34 [==============================] - 14s 424ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1116 - val_mean_absolute_error: 0.1116
#
# Epoch 00030: val_loss did not improve from 0.04136
# Epoch 31/1000
# 34/34 [==============================] - 14s 425ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - val_loss: 0.1091 - val_mean_absolute_error: 0.1091
#
# Epoch 00031: val_loss did not improve from 0.04136
# Epoch 32/1000
# 34/34 [==============================] - 15s 434ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - val_loss: 0.1116 - val_mean_absolute_error: 0.1116
#
# Epoch 00032: val_loss did not improve from 0.04136
# Epoch 33/1000
# 34/34 [==============================] - 15s 435ms/step - loss: 0.0045 - mean_absolute_error: 0.0045 - val_loss: 0.1112 - val_mean_absolute_error: 0.1112
#
# Epoch 00033: val_loss did not improve from 0.04136
# Epoch 34/1000
# 34/34 [==============================] - 14s 426ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1069 - val_mean_absolute_error: 0.1069
#
# Epoch 00034: val_loss did not improve from 0.04136
# Epoch 35/1000
# 34/34 [==============================] - 15s 430ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - val_loss: 0.1082 - val_mean_absolute_error: 0.1082
#
# Epoch 00035: val_loss did not improve from 0.04136
# Epoch 36/1000
# 34/34 [==============================] - 15s 432ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - val_loss: 0.1107 - val_mean_absolute_error: 0.1107
#
# Epoch 00036: val_loss did not improve from 0.04136
# Epoch 37/1000
# 34/34 [==============================] - 15s 428ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1156 - val_mean_absolute_error: 0.1156
#
# Epoch 00037: val_loss did not improve from 0.04136
# Epoch 38/1000
# 34/34 [==============================] - 14s 424ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1132 - val_mean_absolute_error: 0.1132
#
# Epoch 00038: val_loss did not improve from 0.04136
# Epoch 39/1000
# 34/34 [==============================] - 15s 429ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1111 - val_mean_absolute_error: 0.1111
#
# Epoch 00039: val_loss did not improve from 0.04136
# Epoch 40/1000
# 34/34 [==============================] - 15s 428ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.1140 - val_mean_absolute_error: 0.1140
#
# Epoch 00040: val_loss did not improve from 0.04136
# Epoch 41/1000
# 34/34 [==============================] - 15s 433ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1214 - val_mean_absolute_error: 0.1214
#
# Epoch 00041: val_loss did not improve from 0.04136
# Epoch 42/1000
# 34/34 [==============================] - 15s 430ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - val_loss: 0.1192 - val_mean_absolute_error: 0.1192
#
# Epoch 00042: val_loss did not improve from 0.04136
# Epoch 43/1000
# 34/34 [==============================] - 14s 423ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1176 - val_mean_absolute_error: 0.1176
#
# Epoch 00043: val_loss did not improve from 0.04136
# Epoch 44/1000
# 34/34 [==============================] - 15s 432ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1238 - val_mean_absolute_error: 0.1238
#
# Epoch 00044: val_loss did not improve from 0.04136
# Epoch 45/1000
# 34/34 [==============================] - 15s 428ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1244 - val_mean_absolute_error: 0.1244
#
# Epoch 00045: val_loss did not improve from 0.04136
# Epoch 46/1000
# 34/34 [==============================] - 15s 430ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1269 - val_mean_absolute_error: 0.1269
#
# Epoch 00046: val_loss did not improve from 0.04136
# Epoch 47/1000
# 34/34 [==============================] - 14s 425ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1219 - val_mean_absolute_error: 0.1219
#
# Epoch 00047: val_loss did not improve from 0.04136
# Epoch 48/1000
# 34/34 [==============================] - 14s 422ms/step - loss: 0.0043 - mean_absolute_error: 0.0043 - val_loss: 0.1252 - val_mean_absolute_error: 0.1252
#
# Epoch 00048: val_loss did not improve from 0.04136
# Epoch 49/1000
# 34/34 [==============================] - 14s 425ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1291 - val_mean_absolute_error: 0.1291
#
# Epoch 00049: val_loss did not improve from 0.04136
# Epoch 50/1000
# 34/34 [==============================] - 14s 426ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1256 - val_mean_absolute_error: 0.1256
#
# Epoch 00050: val_loss did not improve from 0.04136
# Epoch 51/1000
# 34/34 [==============================] - 14s 417ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1213 - val_mean_absolute_error: 0.1213
#
# Epoch 00051: val_loss did not improve from 0.04136
# Epoch 52/1000
# 34/34 [==============================] - 15s 428ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - val_loss: 0.1261 - val_mean_absolute_error: 0.1261
#
# Epoch 00052: val_loss did not improve from 0.04136
# Epoch 53/1000
# 34/34 [==============================] - 14s 422ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1279 - val_mean_absolute_error: 0.1279
#
# Epoch 00053: val_loss did not improve from 0.04136
# Epoch 54/1000
# 34/34 [==============================] - 14s 427ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1344 - val_mean_absolute_error: 0.1344
#
# Epoch 00054: val_loss did not improve from 0.04136
# Epoch 55/1000
# 34/34 [==============================] - 15s 428ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
#
# Epoch 00055: val_loss did not improve from 0.04136
# Epoch 56/1000
# 34/34 [==============================] - 14s 426ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1383 - val_mean_absolute_error: 0.1383
#
# Epoch 00056: val_loss did not improve from 0.04136
# Epoch 57/1000
# 34/34 [==============================] - 14s 425ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1344 - val_mean_absolute_error: 0.1344
#
# Epoch 00057: val_loss did not improve from 0.04136
# Epoch 58/1000
# 34/34 [==============================] - 14s 426ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1282 - val_mean_absolute_error: 0.1282
#
# Epoch 00058: val_loss did not improve from 0.04136
# Epoch 59/1000
# 34/34 [==============================] - 14s 427ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1211 - val_mean_absolute_error: 0.1211
#
# Epoch 00059: val_loss did not improve from 0.04136
# Epoch 60/1000
# 34/34 [==============================] - 14s 421ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1257 - val_mean_absolute_error: 0.1257
#
# Epoch 00060: val_loss did not improve from 0.04136
# Epoch 61/1000
# 34/34 [==============================] - 15s 429ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1273 - val_mean_absolute_error: 0.1273
#
# Epoch 00061: val_loss did not improve from 0.04136
# Epoch 62/1000
# 34/34 [==============================] - 14s 420ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1273 - val_mean_absolute_error: 0.1273
#
# Epoch 00062: val_loss did not improve from 0.04136
# Epoch 63/1000
# 34/34 [==============================] - 14s 422ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1221 - val_mean_absolute_error: 0.1221
#
# Epoch 00063: val_loss did not improve from 0.04136
# Epoch 64/1000
# 34/34 [==============================] - 14s 425ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.1207 - val_mean_absolute_error: 0.1207
#
# Epoch 00064: val_loss did not improve from 0.04136
# Epoch 65/1000
# 34/34 [==============================] - 9s 275ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - val_loss: 0.1245 - val_mean_absolute_error: 0.1245
#
# Epoch 00065: val_loss did not improve from 0.04136
# Epoch 66/1000
# 34/34 [==============================] - 9s 258ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1251 - val_mean_absolute_error: 0.1251
#
# Epoch 00066: val_loss did not improve from 0.04136
# Epoch 67/1000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1279 - val_mean_absolute_error: 0.1279
#
# Epoch 00067: val_loss did not improve from 0.04136
# Epoch 68/1000
# 34/34 [==============================] - 11s 326ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1342 - val_mean_absolute_error: 0.1342
#
# Epoch 00068: val_loss did not improve from 0.04136
# Epoch 69/1000
# 34/34 [==============================] - 11s 323ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1226 - val_mean_absolute_error: 0.1226
#
# Epoch 00069: val_loss did not improve from 0.04136
# Epoch 70/1000
# 34/34 [==============================] - 11s 327ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.1266 - val_mean_absolute_error: 0.1266
#
# Epoch 00070: val_loss did not improve from 0.04136
# Epoch 71/1000
# 34/34 [==============================] - 11s 329ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1281 - val_mean_absolute_error: 0.1281
#
# Epoch 00071: val_loss did not improve from 0.04136
# Epoch 72/1000
# 34/34 [==============================] - 11s 328ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1284 - val_mean_absolute_error: 0.1284
#
# Epoch 00072: val_loss did not improve from 0.04136
# Epoch 73/1000
# 34/34 [==============================] - 11s 328ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1306 - val_mean_absolute_error: 0.1306
#
# Epoch 00073: val_loss did not improve from 0.04136
# Epoch 74/1000
# 34/34 [==============================] - 11s 327ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1319 - val_mean_absolute_error: 0.1319
#
# Epoch 00074: val_loss did not improve from 0.04136
# Epoch 75/1000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1287 - val_mean_absolute_error: 0.1287
#
# Epoch 00075: val_loss did not improve from 0.04136
# Epoch 76/1000
# 34/34 [==============================] - 11s 329ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1327 - val_mean_absolute_error: 0.1327
#
# Epoch 00076: val_loss did not improve from 0.04136
# Epoch 77/1000
# 34/34 [==============================] - 11s 328ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1300 - val_mean_absolute_error: 0.1300
#
# Epoch 00077: val_loss did not improve from 0.04136
# Epoch 78/1000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1360 - val_mean_absolute_error: 0.1360
#
# Epoch 00078: val_loss did not improve from 0.04136
# Epoch 79/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1326 - val_mean_absolute_error: 0.1326
#
# Epoch 00079: val_loss did not improve from 0.04136
# Epoch 80/1000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.1263 - val_mean_absolute_error: 0.1263
#
# Epoch 00080: val_loss did not improve from 0.04136
# Epoch 81/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1342 - val_mean_absolute_error: 0.1342
#
# Epoch 00081: val_loss did not improve from 0.04136
# Epoch 82/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1277 - val_mean_absolute_error: 0.1277
#
# Epoch 00082: val_loss did not improve from 0.04136
# Epoch 83/1000
# 34/34 [==============================] - 11s 326ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1301 - val_mean_absolute_error: 0.1301
#
# Epoch 00083: val_loss did not improve from 0.04136
# Epoch 84/1000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1298 - val_mean_absolute_error: 0.1298
#
# Epoch 00084: val_loss did not improve from 0.04136
# Epoch 85/1000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1290 - val_mean_absolute_error: 0.1290
#
# Epoch 00085: val_loss did not improve from 0.04136
# Epoch 86/1000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1329 - val_mean_absolute_error: 0.1329
#
# Epoch 00086: val_loss did not improve from 0.04136
# Epoch 87/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1347 - val_mean_absolute_error: 0.1347
#
# Epoch 00087: val_loss did not improve from 0.04136
# Epoch 88/1000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.1280 - val_mean_absolute_error: 0.1280
#
# Epoch 00088: val_loss did not improve from 0.04136
# Epoch 89/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1336 - val_mean_absolute_error: 0.1336
#
# Epoch 00089: val_loss did not improve from 0.04136
# Epoch 90/1000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1235 - val_mean_absolute_error: 0.1235
#
# Epoch 00090: val_loss did not improve from 0.04136
# Epoch 91/1000
# 34/34 [==============================] - 10s 283ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - val_loss: 0.1281 - val_mean_absolute_error: 0.1281
#
# Epoch 00091: val_loss did not improve from 0.04136
# Epoch 92/1000
# 34/34 [==============================] - 10s 281ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1309 - val_mean_absolute_error: 0.1309
#
# Epoch 00092: val_loss did not improve from 0.04136
# Epoch 93/1000
# 34/34 [==============================] - 10s 291ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
#
# Epoch 00093: val_loss did not improve from 0.04136
# Epoch 94/1000
# 34/34 [==============================] - 10s 310ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1316 - val_mean_absolute_error: 0.1316
#
# Epoch 00094: val_loss did not improve from 0.04136
# Epoch 95/1000
# 34/34 [==============================] - 10s 309ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1360 - val_mean_absolute_error: 0.1360
#
# Epoch 00095: val_loss did not improve from 0.04136
# Epoch 96/1000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1335 - val_mean_absolute_error: 0.1335
#
# Epoch 00096: val_loss did not improve from 0.04136
# Epoch 97/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1326 - val_mean_absolute_error: 0.1326
#
# Epoch 00097: val_loss did not improve from 0.04136
# Epoch 98/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1365 - val_mean_absolute_error: 0.1365
#
# Epoch 00098: val_loss did not improve from 0.04136
# Epoch 99/1000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1305 - val_mean_absolute_error: 0.1305
#
# Epoch 00099: val_loss did not improve from 0.04136
# Epoch 100/1000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.1306 - val_mean_absolute_error: 0.1306
#
# Epoch 00100: val_loss did not improve from 0.04136
# Epoch 101/1000
# 34/34 [==============================] - 10s 296ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1346 - val_mean_absolute_error: 0.1346
#
# Epoch 00101: val_loss did not improve from 0.04136
# Epoch 102/1000
# 34/34 [==============================] - 10s 280ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1344 - val_mean_absolute_error: 0.1344
#
# Epoch 00102: val_loss did not improve from 0.04136
# Epoch 103/1000
# 34/34 [==============================] - 9s 279ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1243 - val_mean_absolute_error: 0.1243
#
# Epoch 00103: val_loss did not improve from 0.04136
# Epoch 104/1000
# 34/34 [==============================] - 9s 280ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - val_loss: 0.1331 - val_mean_absolute_error: 0.1331
#
# Epoch 00104: val_loss did not improve from 0.04136
# Epoch 105/1000
# 34/34 [==============================] - 10s 293ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.1303 - val_mean_absolute_error: 0.1303
#
# Epoch 00105: val_loss did not improve from 0.04136
# Epoch 106/1000
# 34/34 [==============================] - 10s 309ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1260 - val_mean_absolute_error: 0.1260
#
# Epoch 00106: val_loss did not improve from 0.04136
# Epoch 107/1000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1228 - val_mean_absolute_error: 0.1228
#
# Epoch 00107: val_loss did not improve from 0.04136
# Epoch 108/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1290 - val_mean_absolute_error: 0.1290
#
# Epoch 00108: val_loss did not improve from 0.04136
# Epoch 109/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1319 - val_mean_absolute_error: 0.1319
#
# Epoch 00109: val_loss did not improve from 0.04136
# Epoch 110/1000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1307 - val_mean_absolute_error: 0.1307
#
# Epoch 00110: val_loss did not improve from 0.04136
# Epoch 111/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1317 - val_mean_absolute_error: 0.1317
#
# Epoch 00111: val_loss did not improve from 0.04136
# Epoch 112/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1345 - val_mean_absolute_error: 0.1345
#
# Epoch 00112: val_loss did not improve from 0.04136
# Epoch 113/1000
# 34/34 [==============================] - 10s 295ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1368 - val_mean_absolute_error: 0.1368
#
# Epoch 00113: val_loss did not improve from 0.04136
# Epoch 114/1000
# 34/34 [==============================] - 10s 286ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1287 - val_mean_absolute_error: 0.1287
#
# Epoch 00114: val_loss did not improve from 0.04136
# Epoch 115/1000
# 34/34 [==============================] - 10s 284ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
#
# Epoch 00115: val_loss did not improve from 0.04136
# Epoch 116/1000
# 34/34 [==============================] - 10s 285ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.1361 - val_mean_absolute_error: 0.1361
#
# Epoch 00116: val_loss did not improve from 0.04136
# Epoch 117/1000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
#
# Epoch 00117: val_loss did not improve from 0.04136
# Epoch 118/1000
# 34/34 [==============================] - 10s 310ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1319 - val_mean_absolute_error: 0.1319
#
# Epoch 00118: val_loss did not improve from 0.04136
# Epoch 119/1000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1312 - val_mean_absolute_error: 0.1312
#
# Epoch 00119: val_loss did not improve from 0.04136
# Epoch 120/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1310 - val_mean_absolute_error: 0.1310
#
# Epoch 00120: val_loss did not improve from 0.04136
# Epoch 121/1000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1253 - val_mean_absolute_error: 0.1253
#
# Epoch 00121: val_loss did not improve from 0.04136
# Epoch 122/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - val_loss: 0.1304 - val_mean_absolute_error: 0.1304
#
# Epoch 00122: val_loss did not improve from 0.04136
# Epoch 123/1000
# 34/34 [==============================] - 10s 309ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1344 - val_mean_absolute_error: 0.1344
#
# Epoch 00123: val_loss did not improve from 0.04136
# Epoch 124/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1301 - val_mean_absolute_error: 0.1301
#
# Epoch 00124: val_loss did not improve from 0.04136
# Epoch 125/1000
# 34/34 [==============================] - 10s 310ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1274 - val_mean_absolute_error: 0.1274
#
# Epoch 00125: val_loss did not improve from 0.04136
# Epoch 126/1000
# 34/34 [==============================] - 10s 282ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1304 - val_mean_absolute_error: 0.1304
#
# Epoch 00126: val_loss did not improve from 0.04136
# Epoch 127/1000
# 34/34 [==============================] - 10s 279ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1245 - val_mean_absolute_error: 0.1245
#
# Epoch 00127: val_loss did not improve from 0.04136
# Epoch 128/1000
# 34/34 [==============================] - 10s 284ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1297 - val_mean_absolute_error: 0.1297
#
# Epoch 00128: val_loss did not improve from 0.04136
# Epoch 129/1000
# 34/34 [==============================] - 10s 309ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - val_loss: 0.1354 - val_mean_absolute_error: 0.1354
#
# Epoch 00129: val_loss did not improve from 0.04136
# Epoch 130/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1349 - val_mean_absolute_error: 0.1349
#
# Epoch 00130: val_loss did not improve from 0.04136
# Epoch 131/1000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0043 - mean_absolute_error: 0.0043 - val_loss: 0.1334 - val_mean_absolute_error: 0.1334
#
# Epoch 00131: val_loss did not improve from 0.04136
# Epoch 132/1000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1356 - val_mean_absolute_error: 0.1356
#
# Epoch 00132: val_loss did not improve from 0.04136
# Epoch 133/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1356 - val_mean_absolute_error: 0.1356
#
# Epoch 00133: val_loss did not improve from 0.04136
# Epoch 134/1000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1364 - val_mean_absolute_error: 0.1364
#
# Epoch 00134: val_loss did not improve from 0.04136
# Epoch 135/1000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1388 - val_mean_absolute_error: 0.1388
#
# Epoch 00135: val_loss did not improve from 0.04136
# Epoch 136/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1350 - val_mean_absolute_error: 0.1350
#
# Epoch 00136: val_loss did not improve from 0.04136
# Epoch 137/1000
# 34/34 [==============================] - 10s 287ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1298 - val_mean_absolute_error: 0.1298
#
# Epoch 00137: val_loss did not improve from 0.04136
# Epoch 138/1000
# 34/34 [==============================] - 10s 284ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1345 - val_mean_absolute_error: 0.1345
#
# Epoch 00138: val_loss did not improve from 0.04136
# Epoch 139/1000
# 34/34 [==============================] - 10s 283ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1377 - val_mean_absolute_error: 0.1377
#
# Epoch 00139: val_loss did not improve from 0.04136
# Epoch 140/1000
# 34/34 [==============================] - 10s 283ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1418 - val_mean_absolute_error: 0.1418
#
# Epoch 00140: val_loss did not improve from 0.04136
# Epoch 141/1000
# 34/34 [==============================] - 11s 330ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1392 - val_mean_absolute_error: 0.1392
#
# Epoch 00141: val_loss did not improve from 0.04136
# Epoch 142/1000
# 34/34 [==============================] - 11s 325ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456
#
# Epoch 00142: val_loss did not improve from 0.04136
# Epoch 143/1000
# 34/34 [==============================] - 11s 328ms/step - loss: 0.0041 - mean_absolute_error: 0.0041 - val_loss: 0.1408 - val_mean_absolute_error: 0.1408
#
# Epoch 00143: val_loss did not improve from 0.04136
# Epoch 144/1000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1344 - val_mean_absolute_error: 0.1344
#
# Epoch 00144: val_loss did not improve from 0.04136
# Epoch 145/1000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1351 - val_mean_absolute_error: 0.1351
#
# Epoch 00145: val_loss did not improve from 0.04136
# Epoch 146/1000
# 34/34 [==============================] - 11s 337ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1367 - val_mean_absolute_error: 0.1367
#
# Epoch 00146: val_loss did not improve from 0.04136
# Epoch 147/1000
# 34/34 [==============================] - 11s 329ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1433 - val_mean_absolute_error: 0.1433
#
# Epoch 00147: val_loss did not improve from 0.04136
# Epoch 148/1000
# 34/34 [==============================] - 11s 332ms/step - loss: 0.0042 - mean_absolute_error: 0.0042 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
#
# Epoch 00148: val_loss did not improve from 0.04136
# Epoch 149/1000
# 34/34 [==============================] - 11s 333ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
#
# Epoch 00149: val_loss did not improve from 0.04136
# Epoch 150/1000
# 34/34 [==============================] - 11s 333ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1387 - val_mean_absolute_error: 0.1387
#
# Epoch 00150: val_loss did not improve from 0.04136
# Epoch 151/1000
# 34/34 [==============================] - 11s 324ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1392 - val_mean_absolute_error: 0.1392
#
# Epoch 00151: val_loss did not improve from 0.04136
# Epoch 152/1000
# 34/34 [==============================] - 11s 339ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1375 - val_mean_absolute_error: 0.1375
#
# Epoch 00152: val_loss did not improve from 0.04136
# Epoch 153/1000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1429 - val_mean_absolute_error: 0.1429
#
# Epoch 00153: val_loss did not improve from 0.04136
# Epoch 154/1000
# 34/34 [==============================] - 12s 338ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1442 - val_mean_absolute_error: 0.1442
#
# Epoch 00154: val_loss did not improve from 0.04136
# Epoch 155/1000
# 34/34 [==============================] - 11s 333ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1413 - val_mean_absolute_error: 0.1413
#
# Epoch 00155: val_loss did not improve from 0.04136
# Epoch 156/1000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1437 - val_mean_absolute_error: 0.1437
#
# Epoch 00156: val_loss did not improve from 0.04136
# Epoch 157/1000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.0033 - mean_absolute_error: 0.0033 - val_loss: 0.1346 - val_mean_absolute_error: 0.1346
#
# Epoch 00157: val_loss did not improve from 0.04136
# Epoch 158/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.1422 - val_mean_absolute_error: 0.1422
#
# Epoch 00158: val_loss did not improve from 0.04136
# Epoch 159/1000
# 34/34 [==============================] - 10s 295ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1458 - val_mean_absolute_error: 0.1458
#
# Epoch 00159: val_loss did not improve from 0.04136
# Epoch 160/1000
# 34/34 [==============================] - 10s 287ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1452 - val_mean_absolute_error: 0.1452
#
# Epoch 00160: val_loss did not improve from 0.04136
# Epoch 161/1000
# 34/34 [==============================] - 10s 281ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1459 - val_mean_absolute_error: 0.1459
#
# Epoch 00161: val_loss did not improve from 0.04136
# Epoch 162/1000
# 34/34 [==============================] - 10s 282ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1527 - val_mean_absolute_error: 0.1527
#
# Epoch 00162: val_loss did not improve from 0.04136
# Epoch 163/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1441 - val_mean_absolute_error: 0.1441
#
# Epoch 00163: val_loss did not improve from 0.04136
# Epoch 164/1000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1434 - val_mean_absolute_error: 0.1434
#
# Epoch 00164: val_loss did not improve from 0.04136
# Epoch 165/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1436 - val_mean_absolute_error: 0.1436
#
# Epoch 00165: val_loss did not improve from 0.04136
# Epoch 166/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1509 - val_mean_absolute_error: 0.1509
#
# Epoch 00166: val_loss did not improve from 0.04136
# Epoch 167/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1510 - val_mean_absolute_error: 0.1510
#
# Epoch 00167: val_loss did not improve from 0.04136
# Epoch 168/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1490 - val_mean_absolute_error: 0.1490
#
# Epoch 00168: val_loss did not improve from 0.04136
# Epoch 169/1000
# 34/34 [==============================] - 11s 323ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.1476 - val_mean_absolute_error: 0.1476
#
# Epoch 00169: val_loss did not improve from 0.04136
# Epoch 170/1000
# 34/34 [==============================] - 10s 307ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1439 - val_mean_absolute_error: 0.1439
#
# Epoch 00170: val_loss did not improve from 0.04136
# Epoch 171/1000
# 34/34 [==============================] - 10s 290ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1482 - val_mean_absolute_error: 0.1482
#
# Epoch 00171: val_loss did not improve from 0.04136
# Epoch 172/1000
# 34/34 [==============================] - 10s 281ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1468 - val_mean_absolute_error: 0.1468
#
# Epoch 00172: val_loss did not improve from 0.04136
# Epoch 173/1000
# 34/34 [==============================] - 10s 287ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1459 - val_mean_absolute_error: 0.1459
#
# Epoch 00173: val_loss did not improve from 0.04136
# Epoch 174/1000
# 34/34 [==============================] - 10s 289ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1496 - val_mean_absolute_error: 0.1496
#
# Epoch 00174: val_loss did not improve from 0.04136
# Epoch 175/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1523 - val_mean_absolute_error: 0.1523
#
# Epoch 00175: val_loss did not improve from 0.04136
# Epoch 176/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1484 - val_mean_absolute_error: 0.1484
#
# Epoch 00176: val_loss did not improve from 0.04136
# Epoch 177/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1472 - val_mean_absolute_error: 0.1472
#
# Epoch 00177: val_loss did not improve from 0.04136
# Epoch 178/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1499 - val_mean_absolute_error: 0.1499
#
# Epoch 00178: val_loss did not improve from 0.04136
# Epoch 179/1000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1483 - val_mean_absolute_error: 0.1483
#
# Epoch 00179: val_loss did not improve from 0.04136
# Epoch 180/1000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1541 - val_mean_absolute_error: 0.1541
#
# Epoch 00180: val_loss did not improve from 0.04136
# Epoch 181/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1590 - val_mean_absolute_error: 0.1590
#
# Epoch 00181: val_loss did not improve from 0.04136
# Epoch 182/1000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.0043 - mean_absolute_error: 0.0043 - val_loss: 0.1500 - val_mean_absolute_error: 0.1500
#
# Epoch 00182: val_loss did not improve from 0.04136
# Epoch 183/1000
# 34/34 [==============================] - 10s 283ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1466 - val_mean_absolute_error: 0.1466
#
# Epoch 00183: val_loss did not improve from 0.04136
# Epoch 184/1000
# 34/34 [==============================] - 10s 280ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1525 - val_mean_absolute_error: 0.1525
#
# Epoch 00184: val_loss did not improve from 0.04136
# Epoch 185/1000
# 34/34 [==============================] - 10s 287ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1502 - val_mean_absolute_error: 0.1502
#
# Epoch 00185: val_loss did not improve from 0.04136
# Epoch 186/1000
# 34/34 [==============================] - 10s 293ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1546 - val_mean_absolute_error: 0.1546
#
# Epoch 00186: val_loss did not improve from 0.04136
# Epoch 187/1000
# 34/34 [==============================] - 10s 309ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1548 - val_mean_absolute_error: 0.1548
#
# Epoch 00187: val_loss did not improve from 0.04136
# Epoch 188/1000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.1534 - val_mean_absolute_error: 0.1534
#
# Epoch 00188: val_loss did not improve from 0.04136
# Epoch 189/1000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.0039 - mean_absolute_error: 0.0039 - val_loss: 0.1531 - val_mean_absolute_error: 0.1531
#
# Epoch 00189: val_loss did not improve from 0.04136
# Epoch 190/1000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1590 - val_mean_absolute_error: 0.1590
#
# Epoch 00190: val_loss did not improve from 0.04136
# Epoch 191/1000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1588 - val_mean_absolute_error: 0.1588
#
# Epoch 00191: val_loss did not improve from 0.04136
# Epoch 192/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1568 - val_mean_absolute_error: 0.1568
#
# Epoch 00192: val_loss did not improve from 0.04136
# Epoch 193/1000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1573 - val_mean_absolute_error: 0.1573
#
# Epoch 00193: val_loss did not improve from 0.04136
# Epoch 194/1000
# 34/34 [==============================] - 10s 299ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1591 - val_mean_absolute_error: 0.1591
#
# Epoch 00194: val_loss did not improve from 0.04136
# Epoch 195/1000
# 34/34 [==============================] - 10s 281ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1609 - val_mean_absolute_error: 0.1609
#
# Epoch 00195: val_loss did not improve from 0.04136
# Epoch 196/1000
# 34/34 [==============================] - 10s 285ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1557 - val_mean_absolute_error: 0.1557
#
# Epoch 00196: val_loss did not improve from 0.04136
# Epoch 197/1000
# 34/34 [==============================] - 10s 281ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1552 - val_mean_absolute_error: 0.1552
#
# Epoch 00197: val_loss did not improve from 0.04136
# Epoch 198/1000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1548 - val_mean_absolute_error: 0.1548
#
# Epoch 00198: val_loss did not improve from 0.04136
# Epoch 199/1000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1554 - val_mean_absolute_error: 0.1554
#
# Epoch 00199: val_loss did not improve from 0.04136
# Epoch 200/1000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.1580 - val_mean_absolute_error: 0.1580
#
# Epoch 00200: val_loss did not improve from 0.04136
# Epoch 201/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1592 - val_mean_absolute_error: 0.1592
#
# Epoch 00201: val_loss did not improve from 0.04136
# Epoch 202/1000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
#
# Epoch 00202: val_loss did not improve from 0.04136
# Epoch 203/1000
# 34/34 [==============================] - 10s 308ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1571 - val_mean_absolute_error: 0.1571
#
# Epoch 00203: val_loss did not improve from 0.04136
# Epoch 204/1000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - val_loss: 0.1620 - val_mean_absolute_error: 0.1620
#
# Epoch 00204: val_loss did not improve from 0.04136
# Epoch 205/1000
# 34/34 [==============================] - 10s 309ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1593 - val_mean_absolute_error: 0.1593
#
# Epoch 00205: val_loss did not improve from 0.04136
# Epoch 206/1000
# 34/34 [==============================] - 10s 282ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.1673 - val_mean_absolute_error: 0.1673
#
# Epoch 00206: val_loss did not improve from 0.04136
# Epoch 207/1000
# 34/34 [==============================] - 10s 281ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.1671 - val_mean_absolute_error: 0.1671
#
# Epoch 00207: val_loss did not improve from 0.04136
# Epoch 208/1000
# 34/34 [==============================] - 10s 284ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1678 - val_mean_absolute_error: 0.1678
#
# Epoch 00208: val_loss did not improve from 0.04136
# Epoch 209/1000
# 34/34 [==============================] - 9s 280ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1671 - val_mean_absolute_error: 0.1671
#
# Epoch 00209: val_loss did not improve from 0.04136
# Epoch 210/1000
# 34/34 [==============================] - 10s 308ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1697 - val_mean_absolute_error: 0.1697
#
# Epoch 00210: val_loss did not improve from 0.04136
# Epoch 211/1000
# 34/34 [==============================] - 10s 309ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.1695 - val_mean_absolute_error: 0.1695
#
# Epoch 00211: val_loss did not improve from 0.04136
# Epoch 212/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0033 - mean_absolute_error: 0.0033 - val_loss: 0.1692 - val_mean_absolute_error: 0.1692
#
# Epoch 00212: val_loss did not improve from 0.04136
# Epoch 213/1000
# 34/34 [==============================] - 10s 307ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.1716 - val_mean_absolute_error: 0.1716
#
# Epoch 00213: val_loss did not improve from 0.04136
# Epoch 214/1000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.1703 - val_mean_absolute_error: 0.1703
#
# Epoch 00214: val_loss did not improve from 0.04136
# Epoch 215/1000
# 34/34 [==============================] - 10s 309ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.1666 - val_mean_absolute_error: 0.1666
#
# Epoch 00215: val_loss did not improve from 0.04136
# Epoch 216/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1696 - val_mean_absolute_error: 0.1696
#
# Epoch 00216: val_loss did not improve from 0.04136
# Epoch 217/1000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.1703 - val_mean_absolute_error: 0.1703
#
# ...
#
# Epoch 00928: val_loss did not improve from 0.04136
# Epoch 929/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2284 - val_mean_absolute_error: 0.2284
#
# Epoch 00929: val_loss did not improve from 0.04136
# Epoch 930/1000
# 34/34 [==============================] - 10s 305ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2299 - val_mean_absolute_error: 0.2299
#
# Epoch 00930: val_loss did not improve from 0.04136
# Epoch 931/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2292 - val_mean_absolute_error: 0.2292
#
# Epoch 00931: val_loss did not improve from 0.04136
# Epoch 932/1000
# 34/34 [==============================] - 10s 305ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2289 - val_mean_absolute_error: 0.2289
#
# Epoch 00932: val_loss did not improve from 0.04136
# Epoch 933/1000
# 34/34 [==============================] - 10s 305ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2288 - val_mean_absolute_error: 0.2288
#
# Epoch 00933: val_loss did not improve from 0.04136
# Epoch 934/1000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2278 - val_mean_absolute_error: 0.2278
#
# Epoch 00934: val_loss did not improve from 0.04136
# Epoch 935/1000
# 34/34 [==============================] - 9s 280ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2280 - val_mean_absolute_error: 0.2280
#
# Epoch 00935: val_loss did not improve from 0.04136
# Epoch 936/1000
# 34/34 [==============================] - 9s 276ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2297 - val_mean_absolute_error: 0.2297
#
# Epoch 00936: val_loss did not improve from 0.04136
# Epoch 937/1000
# 34/34 [==============================] - 10s 280ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2286 - val_mean_absolute_error: 0.2286
#
# Epoch 00937: val_loss did not improve from 0.04136
# Epoch 938/1000
# 34/34 [==============================] - 10s 285ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2264 - val_mean_absolute_error: 0.2264
#
# Epoch 00938: val_loss did not improve from 0.04136
# Epoch 939/1000
# 34/34 [==============================] - 10s 298ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2282 - val_mean_absolute_error: 0.2282
#
# Epoch 00939: val_loss did not improve from 0.04136
# Epoch 940/1000
# 34/34 [==============================] - 10s 305ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2282 - val_mean_absolute_error: 0.2282
#
# Epoch 00940: val_loss did not improve from 0.04136
# Epoch 941/1000
# 34/34 [==============================] - 11s 327ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2299 - val_mean_absolute_error: 0.2299
#
# Epoch 00941: val_loss did not improve from 0.04136
# Epoch 942/1000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2296 - val_mean_absolute_error: 0.2296
#
# Epoch 00942: val_loss did not improve from 0.04136
# Epoch 943/1000
# 34/34 [==============================] - 10s 310ms/step - loss: 0.0027 - mean_absolute_error: 0.0027 - val_loss: 0.2278 - val_mean_absolute_error: 0.2278
#
# Epoch 00943: val_loss did not improve from 0.04136
# Epoch 944/1000
# 34/34 [==============================] - 10s 308ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2294 - val_mean_absolute_error: 0.2294
#
# Epoch 00944: val_loss did not improve from 0.04136
# Epoch 945/1000
# 34/34 [==============================] - 10s 309ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2287 - val_mean_absolute_error: 0.2287
#
# Epoch 00945: val_loss did not improve from 0.04136
# Epoch 946/1000
# 34/34 [==============================] - 10s 299ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2312 - val_mean_absolute_error: 0.2312
#
# Epoch 00946: val_loss did not improve from 0.04136
# Epoch 947/1000
# 34/34 [==============================] - 10s 279ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2289 - val_mean_absolute_error: 0.2289
#
# Epoch 00947: val_loss did not improve from 0.04136
# Epoch 948/1000
# 34/34 [==============================] - 9s 277ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2307 - val_mean_absolute_error: 0.2307
#
# Epoch 00948: val_loss did not improve from 0.04136
# Epoch 949/1000
# 34/34 [==============================] - 9s 273ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2308 - val_mean_absolute_error: 0.2308
#
# Epoch 00949: val_loss did not improve from 0.04136
# Epoch 950/1000
# 34/34 [==============================] - 9s 278ms/step - loss: 0.0027 - mean_absolute_error: 0.0027 - val_loss: 0.2300 - val_mean_absolute_error: 0.2300
#
# Epoch 00950: val_loss did not improve from 0.04136
# Epoch 951/1000
# 34/34 [==============================] - 10s 295ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2310 - val_mean_absolute_error: 0.2310
#
# Epoch 00951: val_loss did not improve from 0.04136
# Epoch 952/1000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2306 - val_mean_absolute_error: 0.2306
#
# Epoch 00952: val_loss did not improve from 0.04136
# Epoch 953/1000
# 34/34 [==============================] - 10s 304ms/step - loss: 0.0027 - mean_absolute_error: 0.0027 - val_loss: 0.2306 - val_mean_absolute_error: 0.2306
#
# Epoch 00953: val_loss did not improve from 0.04136
# Epoch 954/1000
# 34/34 [==============================] - 10s 305ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2301 - val_mean_absolute_error: 0.2301
#
# Epoch 00954: val_loss did not improve from 0.04136
# Epoch 955/1000
# 34/34 [==============================] - 10s 307ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2311 - val_mean_absolute_error: 0.2311
#
# Epoch 00955: val_loss did not improve from 0.04136
# Epoch 956/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0027 - mean_absolute_error: 0.0027 - val_loss: 0.2293 - val_mean_absolute_error: 0.2293
#
# Epoch 00956: val_loss did not improve from 0.04136
# Epoch 957/1000
# 34/34 [==============================] - 10s 307ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2314 - val_mean_absolute_error: 0.2314
#
# Epoch 00957: val_loss did not improve from 0.04136
# Epoch 958/1000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2311 - val_mean_absolute_error: 0.2311
#
# Epoch 00958: val_loss did not improve from 0.04136
# Epoch 959/1000
# 34/34 [==============================] - 9s 275ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2308 - val_mean_absolute_error: 0.2308
#
# Epoch 00959: val_loss did not improve from 0.04136
# Epoch 960/1000
# 34/34 [==============================] - 9s 278ms/step - loss: 0.0027 - mean_absolute_error: 0.0027 - val_loss: 0.2292 - val_mean_absolute_error: 0.2292
#
# Epoch 00960: val_loss did not improve from 0.04136
# Epoch 961/1000
# 34/34 [==============================] - 9s 277ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2287 - val_mean_absolute_error: 0.2287
#
# Epoch 00961: val_loss did not improve from 0.04136
# Epoch 962/1000
# 34/34 [==============================] - 9s 274ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2303 - val_mean_absolute_error: 0.2303
#
# Epoch 00962: val_loss did not improve from 0.04136
# Epoch 963/1000
# 34/34 [==============================] - 10s 296ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2292 - val_mean_absolute_error: 0.2292
#
# Epoch 00963: val_loss did not improve from 0.04136
# Epoch 964/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2291 - val_mean_absolute_error: 0.2291
#
# Epoch 00964: val_loss did not improve from 0.04136
# Epoch 965/1000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2295 - val_mean_absolute_error: 0.2295
#
# Epoch 00965: val_loss did not improve from 0.04136
# Epoch 966/1000
# 34/34 [==============================] - 10s 305ms/step - loss: 0.0027 - mean_absolute_error: 0.0027 - val_loss: 0.2303 - val_mean_absolute_error: 0.2303
#
# Epoch 00966: val_loss did not improve from 0.04136
# Epoch 967/1000
# 34/34 [==============================] - 10s 309ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2301 - val_mean_absolute_error: 0.2301
#
# Epoch 00967: val_loss did not improve from 0.04136
# Epoch 968/1000
# 34/34 [==============================] - 10s 307ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2307 - val_mean_absolute_error: 0.2307
#
# Epoch 00968: val_loss did not improve from 0.04136
# Epoch 969/1000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2308 - val_mean_absolute_error: 0.2308
#
# Epoch 00969: val_loss did not improve from 0.04136
# Epoch 970/1000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2283 - val_mean_absolute_error: 0.2283
#
# Epoch 00970: val_loss did not improve from 0.04136
# Epoch 971/1000
# 34/34 [==============================] - 10s 287ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2306 - val_mean_absolute_error: 0.2306
#
# Epoch 00971: val_loss did not improve from 0.04136
# Epoch 972/1000
# 34/34 [==============================] - 9s 279ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2315 - val_mean_absolute_error: 0.2315
#
# Epoch 00972: val_loss did not improve from 0.04136
# Epoch 973/1000
# 34/34 [==============================] - 9s 278ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2314 - val_mean_absolute_error: 0.2314
#
# Epoch 00973: val_loss did not improve from 0.04136
# Epoch 974/1000
# 34/34 [==============================] - 10s 283ms/step - loss: 0.0022 - mean_absolute_error: 0.0022 - val_loss: 0.2317 - val_mean_absolute_error: 0.2317
#
# Epoch 00974: val_loss did not improve from 0.04136
# Epoch 975/1000
# 34/34 [==============================] - 10s 294ms/step - loss: 0.0027 - mean_absolute_error: 0.0027 - val_loss: 0.2302 - val_mean_absolute_error: 0.2302
#
# Epoch 00975: val_loss did not improve from 0.04136
# Epoch 976/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0023 - mean_absolute_error: 0.0023 - val_loss: 0.2297 - val_mean_absolute_error: 0.2297
#
# Epoch 00976: val_loss did not improve from 0.04136
# Epoch 977/1000
# 34/34 [==============================] - 10s 304ms/step - loss: 0.0023 - mean_absolute_error: 0.0023 - val_loss: 0.2320 - val_mean_absolute_error: 0.2320
#
# Epoch 00977: val_loss did not improve from 0.04136
# Epoch 978/1000
# 34/34 [==============================] - 10s 304ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2278 - val_mean_absolute_error: 0.2278
#
# Epoch 00978: val_loss did not improve from 0.04136
# Epoch 979/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2294 - val_mean_absolute_error: 0.2294
#
# Epoch 00979: val_loss did not improve from 0.04136
# Epoch 980/1000
# 34/34 [==============================] - 10s 304ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2286 - val_mean_absolute_error: 0.2286
#
# Epoch 00980: val_loss did not improve from 0.04136
# Epoch 981/1000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0023 - mean_absolute_error: 0.0023 - val_loss: 0.2298 - val_mean_absolute_error: 0.2298
#
# Epoch 00981: val_loss did not improve from 0.04136
# Epoch 982/1000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.0023 - mean_absolute_error: 0.0023 - val_loss: 0.2281 - val_mean_absolute_error: 0.2281
#
# Epoch 00982: val_loss did not improve from 0.04136
# Epoch 983/1000
# 34/34 [==============================] - 10s 292ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2290 - val_mean_absolute_error: 0.2290
#
# Epoch 00983: val_loss did not improve from 0.04136
# Epoch 984/1000
# 34/34 [==============================] - 9s 277ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2295 - val_mean_absolute_error: 0.2295
#
# Epoch 00984: val_loss did not improve from 0.04136
# Epoch 985/1000
# 34/34 [==============================] - 9s 280ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2306 - val_mean_absolute_error: 0.2306
#
# Epoch 00985: val_loss did not improve from 0.04136
# Epoch 986/1000
# 34/34 [==============================] - 9s 274ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2289 - val_mean_absolute_error: 0.2289
#
# Epoch 00986: val_loss did not improve from 0.04136
# Epoch 987/1000
# 34/34 [==============================] - 10s 294ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2310 - val_mean_absolute_error: 0.2310
#
# Epoch 00987: val_loss did not improve from 0.04136
# Epoch 988/1000
# 34/34 [==============================] - 10s 308ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2296 - val_mean_absolute_error: 0.2296
#
# Epoch 00988: val_loss did not improve from 0.04136
# Epoch 989/1000
# 34/34 [==============================] - 10s 304ms/step - loss: 0.0026 - mean_absolute_error: 0.0026 - val_loss: 0.2279 - val_mean_absolute_error: 0.2279
#
# Epoch 00989: val_loss did not improve from 0.04136
# Epoch 990/1000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.0029 - mean_absolute_error: 0.0029 - val_loss: 0.2294 - val_mean_absolute_error: 0.2294
#
# Epoch 00990: val_loss did not improve from 0.04136
# Epoch 991/1000
# 34/34 [==============================] - 10s 307ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2301 - val_mean_absolute_error: 0.2301
#
# Epoch 00991: val_loss did not improve from 0.04136
# Epoch 992/1000
# 34/34 [==============================] - 10s 308ms/step - loss: 0.0023 - mean_absolute_error: 0.0023 - val_loss: 0.2295 - val_mean_absolute_error: 0.2295
#
# Epoch 00992: val_loss did not improve from 0.04136
# Epoch 993/1000
# 34/34 [==============================] - 10s 307ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2309 - val_mean_absolute_error: 0.2309
#
# Epoch 00993: val_loss did not improve from 0.04136
# Epoch 994/1000
# 34/34 [==============================] - 10s 304ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2306 - val_mean_absolute_error: 0.2306
#
# Epoch 00994: val_loss did not improve from 0.04136
# Epoch 995/1000
# 34/34 [==============================] - 10s 285ms/step - loss: 0.0023 - mean_absolute_error: 0.0023 - val_loss: 0.2297 - val_mean_absolute_error: 0.2297
#
# Epoch 00995: val_loss did not improve from 0.04136
# Epoch 996/1000
# 34/34 [==============================] - 9s 275ms/step - loss: 0.0023 - mean_absolute_error: 0.0023 - val_loss: 0.2296 - val_mean_absolute_error: 0.2296
#
# Epoch 00996: val_loss did not improve from 0.04136
# Epoch 997/1000
# 34/34 [==============================] - 9s 277ms/step - loss: 0.0024 - mean_absolute_error: 0.0024 - val_loss: 0.2303 - val_mean_absolute_error: 0.2303
#
# Epoch 00997: val_loss did not improve from 0.04136
# Epoch 998/1000
# 34/34 [==============================] - 9s 275ms/step - loss: 0.0023 - mean_absolute_error: 0.0023 - val_loss: 0.2300 - val_mean_absolute_error: 0.2300
#
# Epoch 00998: val_loss did not improve from 0.04136
# Epoch 999/1000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.2302 - val_mean_absolute_error: 0.2302
#
# Epoch 00999: val_loss did not improve from 0.04136
# Epoch 1000/1000
# 34/34 [==============================] - 10s 310ms/step - loss: 0.0023 - mean_absolute_error: 0.0023 - val_loss: 0.2307 - val_mean_absolute_error: 0.2307
#
# Epoch 01000: val_loss did not improve from 0.04136

# %%
#Save the Model for import later

# Save model as JSON
tslamodel_10day = model.to_json()

file_path = Path("tslamodel_10day.json")
with open(file_path, "w") as json_file:
    json_file.write(tslamodel_10day)

# Save weights
tslamodel_10day_file_path = ("tslamodel_10day.h5")
model.save_weights("tslamodel_10day.h5")

# %%
import matplotlib.pyplot as plt

def plot_graph(test_df):
    """
    This function plots true close price along with predicted close price
    with blue and red colors respectively
    """
    plt.plot(test_df[f'true_adjclose_{LOOKUP_STEP}'], c='b')
    plt.plot(test_df[f'adjclose_{LOOKUP_STEP}'], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\jacob\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
def get_final_df(model, data):
    """
    This function takes the `model` and `data` dict to 
    construct a final dataframe that includes the features along 
    with true and predicted prices of the testing dataset
    """
    # if predicted future price is higher than the current, 
    # then calculate the true future price minus the current price, to get the buy profit
    buy_profit  = lambda current, true_future, pred_future: true_future - current if pred_future > current else 0
    # if the predicted future price is lower than the current price,
    # then subtract the true future price from the current price
    sell_profit = lambda current, true_future, pred_future: current - true_future if pred_future < current else 0
    X_test = data["X_test"]
    y_test = data["y_test"]
    # perform prediction and get prices
    y_pred = model.predict(X_test)
    if SCALE:
        y_test = np.squeeze(data["column_scaler"]["Adj Close"].inverse_transform(np.expand_dims(y_test, axis=0)))
        y_pred = np.squeeze(data["column_scaler"]["Adj Close"].inverse_transform(y_pred))
    test_df = data["test_df"]
    # add predicted future prices to the dataframe
    test_df[f"adjclose_{LOOKUP_STEP}"] = y_pred
    # add true future prices to the dataframe
    test_df[f"true_adjclose_{LOOKUP_STEP}"] = y_test
    # sort the dataframe by date
    test_df.sort_index(inplace=True)
    final_df = test_df
    # add the buy profit column
    final_df["buy_profit"] = list(map(buy_profit, 
                                    final_df["Adj Close"], 
                                    final_df[f"adjclose_{LOOKUP_STEP}"], 
                                    final_df[f"true_adjclose_{LOOKUP_STEP}"])
                                    # since we don't have profit for last sequence, add 0's
                                    )
    # add the sell profit column
    final_df["sell_profit"] = list(map(sell_profit, 
                                    final_df["Adj Close"], 
                                    final_df[f"adjclose_{LOOKUP_STEP}"], 
                                    final_df[f"true_adjclose_{LOOKUP_STEP}"])
                                    # since we don't have profit for last sequence, add 0's
                                    )
    return final_df

# %%
def predict(model, data):
    # retrieve the last sequence from data
    last_sequence = data["last_sequence"][-N_STEPS:]
    # expand dimension
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    if SCALE:
        predicted_price = data["column_scaler"]["Adj Close"].inverse_transform(prediction)[0][0]
    else:
        predicted_price = prediction[0][0]# load optimal model weights from results folder
    model_path = os.path.join("results", model_name) + ".h5"
    model.load_weights(model_path)
    return predicted_price

# %%
# load optimal model weights from results folder
model_path = os.path.join("results", model_name) + ".h5"
model.load_weights(model_path)

# %%
# evaluate the model
loss, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
if SCALE:
    mean_absolute_error = data["column_scaler"]["Adj Close"].inverse_transform([[mae]])[0][0]
else:
    mean_absolute_error = mae

# %%
# predict the future price
final_df = get_final_df(model, data)

# predict the future price
future_price = predict(model, data)

final_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-06   63.917999   64.848000   63.124001   63.444000   63.444000
# 2019-02-07   62.660000   62.939999   60.599998   61.501999   61.501999
# 2019-02-08   61.366001   61.490002   59.700001   61.160000   61.160000
# 2019-02-11   62.320000   63.720001   62.099998   62.568001   62.568001
# 2019-02-12   63.240002   63.638000   61.924000   62.362000   62.362000
# ...                ...         ...         ...         ...         ...
# 2021-03-09  608.179993  678.090027  595.210022  673.580017  673.580017
# 2021-03-10  700.299988  717.849976  655.059998  668.059998  668.059998
# 2021-03-11  699.400024  702.500000  677.179993  699.599976  699.599976
# 2021-03-12  670.000000  694.880005  666.140015  693.729980  693.729980
# 2021-03-15  694.090027  713.179993  684.039978  707.940002  707.940002
#
#               Volume  adjclose_10  true_adjclose_10  buy_profit  sell_profit
# Date
# 2019-02-06  25192500    65.181435         58.245998    0.000000    -1.737434
# 2019-02-07  32603000    65.189575         58.942001    0.000000    -3.687576
# 2019-02-08  29221000    65.093666         59.754002    0.000000    -3.933666
# 2019-02-11  35648500    65.175964         59.571999    0.000000    -2.607964
# 2019-02-12  27588000    65.245934         62.948002    2.883934     0.000000
# ...              ...          ...               ...         ...          ...
# 2021-03-09  67523300   620.444031        662.159973    0.000000    53.135986
# 2021-03-10  60605700   615.980408        630.270020    0.000000    52.079590
# 2021-03-11  36253900   615.365540        640.390015    0.000000    84.234436
# 2021-03-12  33583800   616.078430        618.710022    0.000000    77.651550
# 2021-03-15  29335600   618.675964        611.289978    0.000000    89.264038
#
# [530 rows x 10 columns]

# %%
# we calculate the accuracy by counting the number of positive profits
accuracy_score = (len(final_df[final_df['sell_profit'] > 0]) + len(final_df[final_df['buy_profit'] > 0])) / len(final_df)
# calculating total buy & sell profit
total_buy_profit  = final_df["buy_profit"].sum()
total_sell_profit = final_df["sell_profit"].sum()
# total profit by adding sell & buy together
total_profit = total_buy_profit + total_sell_profit
# dividing total profit by number of testing samples (number of trades)
profit_per_trade = total_profit / len(final_df)

# %%
# printing metrics
print(f"Future price after {LOOKUP_STEP} days is {future_price:.2f}$")
print(f"{LOSS} loss:", loss)
print("Mean Absolute Error:", mean_absolute_error)
print("Accuracy score:", accuracy_score)
print("Total buy profit:", total_buy_profit)
print("Total sell profit:", total_sell_profit)
print("Total profit:", total_profit)
print("Profit per trade:", profit_per_trade)
# Out:
# Future price after 10 days is 608.93$
# mae loss: 0.04135701805353165
# Mean Absolute Error: 39.5512820887872
# Accuracy score: 0.4830188679245283
# Total buy profit: -3816.2242431640625
# Total sell profit: 2573.349063873291
# Total profit: -1242.8751792907715
# Profit per trade: -2.3450475080957953

# %%
# printing metrics
print(f"This model predicts the Future price after {LOOKUP_STEP} days will be {future_price:.2f}$")
# plot true/pred prices graph
plot_graph(final_df)
# Out:
# This model predicts the Future price after 10 days will be 608.93$
