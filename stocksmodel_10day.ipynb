# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from yahoo_fin import stock_info as si
from collections import deque
import yfinance as yf
from pathlib import Path

import os
import numpy as np
import pandas as pd
import random

# %%
# set seed, so we can get the same results after rerunning several times
np.random.seed(314)
tf.random.set_seed(314)
random.seed(314)

# %%
def getTickerPriceData(tickers,period='3650d', interval='1d'):
    #Getting Ticker Price Data (Open,High,Close,etc)
    ticker_df = yf.download(tickers=tickers,period=period,interval=interval)
    return ticker_df

# %%
#getTickerPriceData(['TSLA'])

# %%
def shuffle_in_unison(a, b):
    # shuffle two arrays in the same way
    state = np.random.get_state()
    np.random.shuffle(a)
    np.random.set_state(state)
    np.random.shuffle(b)

def load_data(ticker, n_steps=50, scale=True, shuffle=True, lookup_step=1, split_by_date=True,
                test_size=0.2, feature_columns=['Adj Close', 'Volume', 'Open', 'High', 'Low']):
    """
    Loads data from Yahoo Finance source, as well as scaling, shuffling, normalizing and splitting.
    Params:
        ticker (str/pd.DataFrame): the ticker you want to load, examples include AAPL, TESL, etc.
        n_steps (int): the historical sequence length (i.e window size) used to predict, default is 50
        scale (bool): whether to scale prices from 0 to 1, default is True
        shuffle (bool): whether to shuffle the dataset (both training & testing), default is True
        lookup_step (int): the future lookup step to predict, default is 1 (e.g next day)
        split_by_date (bool): whether we split the dataset into training/testing by date, setting it 
            to False will split datasets in a random way
        test_size (float): ratio for test data, default is 0.2 (20% testing data)
        feature_columns (list): the list of features to use to feed into the model, default is everything grabbed from yahoo_fin
    """
    # see if ticker is already a loaded stock from yahoo finance
    if isinstance(ticker, str):
        # load it from yfinance
        df = getTickerPriceData(ticker)
    elif isinstance(ticker, pd.DataFrame):
        # already loaded, use it directly
        df = ticker
    else:
        raise TypeError("ticker can be either a str or a `pd.DataFrame` instances")
    # this will contain all the elements we want to return from this function
    result = {}
    # we will also return the original dataframe itself
    result['df'] = df.copy()
    # make sure that the passed feature_columns exist in the dataframe
    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    # add date as a column
    if "date" not in df.columns:
        df["date"] = df.index
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['Adj Close'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns + ["date"]].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices that are not available in the dataset
    last_sequence = list([s[:len(feature_columns)] for s in sequences]) + list(last_sequence)
    last_sequence = np.array(last_sequence).astype(np.float32)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    if split_by_date:
        # split the dataset into training & testing sets by date (not randomly splitting)
        train_samples = int((1 - test_size) * len(X))
        result["X_train"] = X[:train_samples]
        result["y_train"] = y[:train_samples]
        result["X_test"]  = X[train_samples:]
        result["y_test"]  = y[train_samples:]
        if shuffle:
            # shuffle the datasets for training (if shuffle parameter is set)
            shuffle_in_unison(result["X_train"], result["y_train"])
            shuffle_in_unison(result["X_test"], result["y_test"])
    else:    
        # split the dataset randomly
        result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y, 
                                                                                test_size=test_size, shuffle=shuffle)
    # get the list of test set dates
    dates = result["X_test"][:, -1, -1]
    # retrieve test features from the original dataframe
    result["test_df"] = result["df"].loc[dates]
    # remove duplicated dates in the testing dataframe
    result["test_df"] = result["test_df"][~result["test_df"].index.duplicated(keep='first')]
    # remove dates from the training/testing sets & convert to float32
    result["X_train"] = result["X_train"][:, :, :len(feature_columns)].astype(np.float32)
    result["X_test"] = result["X_test"][:, :, :len(feature_columns)].astype(np.float32)
    return result

# %%
def create_model(sequence_length, n_features, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), batch_input_shape=(None, sequence_length, n_features)))
            else:
                model.add(cell(units, return_sequences=True, batch_input_shape=(None, sequence_length, n_features)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
import os
import time
from tensorflow.keras.layers import LSTM

# Window size or the sequence length
N_STEPS = 50
# Lookup step, 1 is the next day
LOOKUP_STEP = 15
# whether to scale feature columns & output price as well
SCALE = True
scale_str = f"sc-{int(SCALE)}"
# whether to shuffle the dataset
SHUFFLE = False
shuffle_str = f"sh-{int(SHUFFLE)}"
# whether to split the training/testing set by date
SPLIT_BY_DATE = True
split_by_date_str = f"sbd-{int(SPLIT_BY_DATE)}"
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.2
# features to use
FEATURE_COLUMNS = ["Adj Close", "Volume", "Open", "High", "Low"]
# date now
date_now = time.strftime("%Y-%m-%d")
### model parameters
N_LAYERS = 2
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 256
# 40% dropout
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = False
### training parameters
# mean absolute error loss
LOSS = "mae"
# huber loss
#LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 1000
# Apple Stock 
ticker = "AAPL"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{shuffle_str}-{scale_str}-{split_by_date_str}-\
{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

# %%
# create these folders if they does not exist
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")

# %%
# load the data
data = load_data(ticker, N_STEPS, scale=SCALE, split_by_date=SPLIT_BY_DATE, 
                shuffle=SHUFFLE, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, 
                feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv(ticker_data_filename)
# construct the model
model = create_model(N_STEPS, len(FEATURE_COLUMNS), loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
# train the model and save the weights whenever we see 
# a new optimal model using ModelCheckpoint
history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/1000
# 45/45 [==============================] - 18s 340ms/step - loss: 0.0299 - mean_absolute_error: 0.0299 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563
#
# Epoch 00001: val_loss improved from inf to 0.05633, saving model to results\2021-03-30_AAPL-sh-0-sc-1-sbd-1-mae-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 2/1000
# 45/45 [==============================] - 16s 367ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - val_loss: 0.0401 - val_mean_absolute_error: 0.0401
#
# Epoch 00002: val_loss improved from 0.05633 to 0.04006, saving model to results\2021-03-30_AAPL-sh-0-sc-1-sbd-1-mae-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 3/1000
# 45/45 [==============================] - 17s 371ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - val_loss: 0.0477 - val_mean_absolute_error: 0.0477
#
# Epoch 00003: val_loss did not improve from 0.04006
# Epoch 4/1000
# 45/45 [==============================] - 17s 367ms/step - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.0430 - val_mean_absolute_error: 0.0430
#
# Epoch 00004: val_loss did not improve from 0.04006
# Epoch 5/1000
# 45/45 [==============================] - 17s 370ms/step - loss: 0.0098 - mean_absolute_error: 0.0098 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551
#
# Epoch 00005: val_loss did not improve from 0.04006
# Epoch 6/1000
# 45/45 [==============================] - 18s 407ms/step - loss: 0.0097 - mean_absolute_error: 0.0097 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494
#
# Epoch 00006: val_loss did not improve from 0.04006
# Epoch 7/1000
# 45/45 [==============================] - 25s 558ms/step - loss: 0.0099 - mean_absolute_error: 0.0099 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565
#
# Epoch 00007: val_loss did not improve from 0.04006
# Epoch 8/1000
# 45/45 [==============================] - 19s 415ms/step - loss: 0.0099 - mean_absolute_error: 0.0099 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512
#
# Epoch 00008: val_loss did not improve from 0.04006
# Epoch 9/1000
# 45/45 [==============================] - 18s 400ms/step - loss: 0.0094 - mean_absolute_error: 0.0094 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560
#
# Epoch 00009: val_loss did not improve from 0.04006
# Epoch 10/1000
# 45/45 [==============================] - 16s 367ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491
#
# Epoch 00010: val_loss did not improve from 0.04006
# Epoch 11/1000
# 45/45 [==============================] - 19s 418ms/step - loss: 0.0086 - mean_absolute_error: 0.0086 - val_loss: 0.0446 - val_mean_absolute_error: 0.0446
#
# Epoch 00011: val_loss did not improve from 0.04006
# Epoch 12/1000
# 45/45 [==============================] - 18s 394ms/step - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0506 - val_mean_absolute_error: 0.0506
#
# Epoch 00012: val_loss did not improve from 0.04006
# Epoch 13/1000
# 45/45 [==============================] - 17s 371ms/step - loss: 0.0087 - mean_absolute_error: 0.0087 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495
#
# Epoch 00013: val_loss did not improve from 0.04006
# Epoch 14/1000
# 45/45 [==============================] - 17s 372ms/step - loss: 0.0084 - mean_absolute_error: 0.0084 - val_loss: 0.0614 - val_mean_absolute_error: 0.0614
#
# Epoch 00014: val_loss did not improve from 0.04006
# Epoch 15/1000
# 45/45 [==============================] - 17s 373ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - val_loss: 0.0635 - val_mean_absolute_error: 0.0635
#
# Epoch 00015: val_loss did not improve from 0.04006
# Epoch 16/1000
# 45/45 [==============================] - 17s 370ms/step - loss: 0.0085 - mean_absolute_error: 0.0085 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565
#
# Epoch 00016: val_loss did not improve from 0.04006
# Epoch 17/1000
# 45/45 [==============================] - 16s 365ms/step - loss: 0.0087 - mean_absolute_error: 0.0087 - val_loss: 0.0633 - val_mean_absolute_error: 0.0633
#
# Epoch 00017: val_loss did not improve from 0.04006
# Epoch 18/1000
# 45/45 [==============================] - 17s 371ms/step - loss: 0.0086 - mean_absolute_error: 0.0086 - val_loss: 0.0604 - val_mean_absolute_error: 0.0604
#
# Epoch 00018: val_loss did not improve from 0.04006
# Epoch 19/1000
# 45/45 [==============================] - 17s 377ms/step - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0774 - val_mean_absolute_error: 0.0774
#
# Epoch 00019: val_loss did not improve from 0.04006
# Epoch 20/1000
# 45/45 [==============================] - 17s 374ms/step - loss: 0.0084 - mean_absolute_error: 0.0084 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542
#
# Epoch 00020: val_loss did not improve from 0.04006
# Epoch 21/1000
# 45/45 [==============================] - 18s 395ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.0785 - val_mean_absolute_error: 0.0785
#
# Epoch 00021: val_loss did not improve from 0.04006
# Epoch 22/1000
# 45/45 [==============================] - 18s 391ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0633 - val_mean_absolute_error: 0.0633
#
# Epoch 00022: val_loss did not improve from 0.04006
# Epoch 23/1000
# 45/45 [==============================] - 17s 379ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0753 - val_mean_absolute_error: 0.0753
#
# Epoch 00023: val_loss did not improve from 0.04006
# Epoch 24/1000
# 45/45 [==============================] - 18s 400ms/step - loss: 0.0084 - mean_absolute_error: 0.0084 - val_loss: 0.0688 - val_mean_absolute_error: 0.0688
#
# Epoch 00024: val_loss did not improve from 0.04006
# Epoch 25/1000
# 45/45 [==============================] - 17s 382ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.1237 - val_mean_absolute_error: 0.1237
#
# Epoch 00025: val_loss did not improve from 0.04006
# Epoch 26/1000
# 45/45 [==============================] - 18s 394ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.0673 - val_mean_absolute_error: 0.0673
#
# Epoch 00026: val_loss did not improve from 0.04006
# Epoch 27/1000
# 45/45 [==============================] - 17s 378ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.0888 - val_mean_absolute_error: 0.0888
#
# Epoch 00027: val_loss did not improve from 0.04006
# Epoch 28/1000
# 45/45 [==============================] - 17s 384ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.1084 - val_mean_absolute_error: 0.1084
#
# Epoch 00028: val_loss did not improve from 0.04006
# Epoch 29/1000
# 45/45 [==============================] - 17s 388ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - val_loss: 0.0770 - val_mean_absolute_error: 0.0770
#
# Epoch 00029: val_loss did not improve from 0.04006
# Epoch 30/1000
# 45/45 [==============================] - 17s 384ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.0730 - val_mean_absolute_error: 0.0730
#
# Epoch 00030: val_loss did not improve from 0.04006
# Epoch 31/1000
# 45/45 [==============================] - 17s 379ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.0651 - val_mean_absolute_error: 0.0651
#
# Epoch 00031: val_loss did not improve from 0.04006
# Epoch 32/1000
# 45/45 [==============================] - 17s 386ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0817 - val_mean_absolute_error: 0.0817
#
# Epoch 00032: val_loss did not improve from 0.04006
# Epoch 33/1000
# 45/45 [==============================] - 17s 382ms/step - loss: 0.0087 - mean_absolute_error: 0.0087 - val_loss: 0.0806 - val_mean_absolute_error: 0.0806
#
# Epoch 00033: val_loss did not improve from 0.04006
# Epoch 34/1000
# 45/45 [==============================] - 18s 396ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.0745 - val_mean_absolute_error: 0.0745
#
# Epoch 00034: val_loss did not improve from 0.04006
# Epoch 35/1000
# 45/45 [==============================] - 18s 396ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - val_loss: 0.0759 - val_mean_absolute_error: 0.0759
#
# Epoch 00035: val_loss did not improve from 0.04006
# Epoch 36/1000
# 45/45 [==============================] - 17s 381ms/step - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.0901 - val_mean_absolute_error: 0.0901
#
# Epoch 00036: val_loss did not improve from 0.04006
# Epoch 37/1000
# 45/45 [==============================] - 17s 387ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578
#
# Epoch 00037: val_loss did not improve from 0.04006
# Epoch 38/1000
# 45/45 [==============================] - 19s 425ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.0619 - val_mean_absolute_error: 0.0619
#
# Epoch 00038: val_loss did not improve from 0.04006
# Epoch 39/1000
# 45/45 [==============================] - 17s 380ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568
#
# Epoch 00039: val_loss did not improve from 0.04006
# Epoch 40/1000
# 45/45 [==============================] - 17s 381ms/step - loss: 0.0087 - mean_absolute_error: 0.0087 - val_loss: 0.0466 - val_mean_absolute_error: 0.0466
#
# Epoch 00040: val_loss did not improve from 0.04006
# Epoch 41/1000
# 45/45 [==============================] - 17s 370ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.0460 - val_mean_absolute_error: 0.0460
#
# Epoch 00041: val_loss did not improve from 0.04006
# Epoch 42/1000
# 45/45 [==============================] - 17s 374ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.0670 - val_mean_absolute_error: 0.0670
#
# Epoch 00042: val_loss did not improve from 0.04006
# Epoch 43/1000
# 45/45 [==============================] - 17s 372ms/step - loss: 0.0085 - mean_absolute_error: 0.0085 - val_loss: 0.0425 - val_mean_absolute_error: 0.0425
#
# Epoch 00043: val_loss did not improve from 0.04006
# Epoch 44/1000
# 45/45 [==============================] - 18s 400ms/step - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.0431 - val_mean_absolute_error: 0.0431
#
# Epoch 00044: val_loss did not improve from 0.04006
# Epoch 45/1000
# 45/45 [==============================] - 18s 394ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.0429 - val_mean_absolute_error: 0.0429
#
# Epoch 00045: val_loss did not improve from 0.04006
# Epoch 46/1000
# 45/45 [==============================] - 18s 389ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0355 - val_mean_absolute_error: 0.0355
#
# Epoch 00046: val_loss improved from 0.04006 to 0.03550, saving model to results\2021-03-30_AAPL-sh-0-sc-1-sbd-1-mae-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 47/1000
# 45/45 [==============================] - 17s 389ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.0370 - val_mean_absolute_error: 0.0370
#
# Epoch 00047: val_loss did not improve from 0.03550
# Epoch 48/1000
# 45/45 [==============================] - 16s 360ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.0383 - val_mean_absolute_error: 0.0383
#
# Epoch 00048: val_loss did not improve from 0.03550
# Epoch 49/1000
# 45/45 [==============================] - 16s 365ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.0383 - val_mean_absolute_error: 0.0383
#
# Epoch 00049: val_loss did not improve from 0.03550
# Epoch 50/1000
# 45/45 [==============================] - 16s 362ms/step - loss: 0.0083 - mean_absolute_error: 0.0083 - val_loss: 0.0481 - val_mean_absolute_error: 0.0481
#
# Epoch 00050: val_loss did not improve from 0.03550
# Epoch 51/1000
# 45/45 [==============================] - 16s 362ms/step - loss: 0.0084 - mean_absolute_error: 0.0084 - val_loss: 0.0567 - val_mean_absolute_error: 0.0567
#
# Epoch 00051: val_loss did not improve from 0.03550
# Epoch 52/1000
# 45/45 [==============================] - 16s 363ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568
#
# Epoch 00052: val_loss did not improve from 0.03550
# Epoch 53/1000
# 45/45 [==============================] - 16s 359ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.0417 - val_mean_absolute_error: 0.0417
#
# Epoch 00053: val_loss did not improve from 0.03550
# Epoch 54/1000
# 45/45 [==============================] - 16s 360ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518
#
# Epoch 00054: val_loss did not improve from 0.03550
# Epoch 55/1000
# 45/45 [==============================] - 16s 361ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.0415 - val_mean_absolute_error: 0.0415
#
# Epoch 00055: val_loss did not improve from 0.03550
# Epoch 56/1000
# 45/45 [==============================] - 16s 361ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0772 - val_mean_absolute_error: 0.0772
#
# Epoch 00056: val_loss did not improve from 0.03550
# Epoch 57/1000
# 45/45 [==============================] - 15s 342ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495
#
# Epoch 00057: val_loss did not improve from 0.03550
# Epoch 58/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0085 - mean_absolute_error: 0.0085 - val_loss: 0.0712 - val_mean_absolute_error: 0.0712
#
# Epoch 00058: val_loss did not improve from 0.03550
# Epoch 59/1000
# 45/45 [==============================] - 14s 314ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0727 - val_mean_absolute_error: 0.0727
#
# Epoch 00059: val_loss did not improve from 0.03550
# Epoch 60/1000
# 45/45 [==============================] - 14s 315ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0813 - val_mean_absolute_error: 0.0813
#
# Epoch 00060: val_loss did not improve from 0.03550
# Epoch 61/1000
# 45/45 [==============================] - 14s 316ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699
#
# Epoch 00061: val_loss did not improve from 0.03550
# Epoch 62/1000
# 45/45 [==============================] - 15s 325ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0840 - val_mean_absolute_error: 0.0840
#
# Epoch 00062: val_loss did not improve from 0.03550
# Epoch 63/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.0788 - val_mean_absolute_error: 0.0788
#
# Epoch 00063: val_loss did not improve from 0.03550
# Epoch 64/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0932 - val_mean_absolute_error: 0.0932
#
# Epoch 00064: val_loss did not improve from 0.03550
# Epoch 65/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.0888 - val_mean_absolute_error: 0.0888
#
# Epoch 00065: val_loss did not improve from 0.03550
# Epoch 66/1000
# 45/45 [==============================] - 14s 316ms/step - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.0793 - val_mean_absolute_error: 0.0793
#
# Epoch 00066: val_loss did not improve from 0.03550
# Epoch 67/1000
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.1049 - val_mean_absolute_error: 0.1049
#
# Epoch 00067: val_loss did not improve from 0.03550
# Epoch 68/1000
# 45/45 [==============================] - 15s 334ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.1082 - val_mean_absolute_error: 0.1082
#
# Epoch 00068: val_loss did not improve from 0.03550
# Epoch 69/1000
# 45/45 [==============================] - 14s 311ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.1183 - val_mean_absolute_error: 0.1183
#
# Epoch 00069: val_loss did not improve from 0.03550
# Epoch 70/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.1032 - val_mean_absolute_error: 0.1032
#
# Epoch 00070: val_loss did not improve from 0.03550
# Epoch 71/1000
# 45/45 [==============================] - 15s 324ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.1050 - val_mean_absolute_error: 0.1050
#
# Epoch 00071: val_loss did not improve from 0.03550
# Epoch 72/1000
# 45/45 [==============================] - 15s 341ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
#
# Epoch 00072: val_loss did not improve from 0.03550
# Epoch 73/1000
# 45/45 [==============================] - 15s 336ms/step - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978
#
# Epoch 00073: val_loss did not improve from 0.03550
# Epoch 74/1000
# 45/45 [==============================] - 15s 324ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.1171 - val_mean_absolute_error: 0.1171
#
# Epoch 00074: val_loss did not improve from 0.03550
# Epoch 75/1000
# 45/45 [==============================] - 14s 322ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.1301 - val_mean_absolute_error: 0.1301
#
# Epoch 00075: val_loss did not improve from 0.03550
# Epoch 76/1000
# 45/45 [==============================] - 15s 328ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.1215 - val_mean_absolute_error: 0.1215
#
# Epoch 00076: val_loss did not improve from 0.03550
# Epoch 77/1000
# 45/45 [==============================] - 15s 327ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1303 - val_mean_absolute_error: 0.1303
#
# Epoch 00077: val_loss did not improve from 0.03550
# Epoch 78/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.1268 - val_mean_absolute_error: 0.1268
#
# Epoch 00078: val_loss did not improve from 0.03550
# Epoch 79/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.1264 - val_mean_absolute_error: 0.1264
#
# Epoch 00079: val_loss did not improve from 0.03550
# Epoch 80/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1352 - val_mean_absolute_error: 0.1352
#
# Epoch 00080: val_loss did not improve from 0.03550
# Epoch 81/1000
# 45/45 [==============================] - 14s 312ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1198 - val_mean_absolute_error: 0.1198
#
# Epoch 00081: val_loss did not improve from 0.03550
# Epoch 82/1000
# 45/45 [==============================] - 14s 323ms/step - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
#
# Epoch 00082: val_loss did not improve from 0.03550
# Epoch 83/1000
# 45/45 [==============================] - 14s 311ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1549 - val_mean_absolute_error: 0.1549
#
# Epoch 00083: val_loss did not improve from 0.03550
# Epoch 84/1000
# 45/45 [==============================] - 14s 315ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450
#
# Epoch 00084: val_loss did not improve from 0.03550
# Epoch 85/1000
# 45/45 [==============================] - 14s 315ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1593 - val_mean_absolute_error: 0.1593
#
# Epoch 00085: val_loss did not improve from 0.03550
# Epoch 86/1000
# 45/45 [==============================] - 14s 309ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1532 - val_mean_absolute_error: 0.1532
#
# Epoch 00086: val_loss did not improve from 0.03550
# Epoch 87/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1599 - val_mean_absolute_error: 0.1599
#
# Epoch 00087: val_loss did not improve from 0.03550
# Epoch 88/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1683 - val_mean_absolute_error: 0.1683
#
# Epoch 00088: val_loss did not improve from 0.03550
# Epoch 89/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.1605 - val_mean_absolute_error: 0.1605
#
# Epoch 00089: val_loss did not improve from 0.03550
# Epoch 90/1000
# 45/45 [==============================] - 15s 328ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.1602 - val_mean_absolute_error: 0.1602
#
# Epoch 00090: val_loss did not improve from 0.03550
# Epoch 91/1000
# 45/45 [==============================] - 14s 322ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.1736 - val_mean_absolute_error: 0.1736
#
# Epoch 00091: val_loss did not improve from 0.03550
# Epoch 92/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1692 - val_mean_absolute_error: 0.1692
#
# Epoch 00092: val_loss did not improve from 0.03550
# Epoch 93/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.1770 - val_mean_absolute_error: 0.1770
#
# Epoch 00093: val_loss did not improve from 0.03550
# Epoch 94/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.1769 - val_mean_absolute_error: 0.1769
#
# Epoch 00094: val_loss did not improve from 0.03550
# Epoch 95/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1933 - val_mean_absolute_error: 0.1933
#
# Epoch 00095: val_loss did not improve from 0.03550
# Epoch 96/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1859 - val_mean_absolute_error: 0.1859
#
# Epoch 00096: val_loss did not improve from 0.03550
# Epoch 97/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.1873 - val_mean_absolute_error: 0.1873
#
# Epoch 00097: val_loss did not improve from 0.03550
# Epoch 98/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.1774 - val_mean_absolute_error: 0.1774
#
# Epoch 00098: val_loss did not improve from 0.03550
# Epoch 99/1000
# 45/45 [==============================] - 14s 312ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1864 - val_mean_absolute_error: 0.1864
#
# Epoch 00099: val_loss did not improve from 0.03550
# Epoch 100/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.1793 - val_mean_absolute_error: 0.1793
#
# Epoch 00100: val_loss did not improve from 0.03550
# Epoch 101/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.1878 - val_mean_absolute_error: 0.1878
#
# Epoch 00101: val_loss did not improve from 0.03550
# Epoch 102/1000
# 45/45 [==============================] - 14s 310ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1832 - val_mean_absolute_error: 0.1832
#
# Epoch 00102: val_loss did not improve from 0.03550
# Epoch 103/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1908 - val_mean_absolute_error: 0.1908
#
# Epoch 00103: val_loss did not improve from 0.03550
# Epoch 104/1000
# 45/45 [==============================] - 14s 322ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1818 - val_mean_absolute_error: 0.1818
#
# Epoch 00104: val_loss did not improve from 0.03550
# Epoch 105/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1730 - val_mean_absolute_error: 0.1730
#
# Epoch 00105: val_loss did not improve from 0.03550
# Epoch 106/1000
# 45/45 [==============================] - 14s 323ms/step - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.1978 - val_mean_absolute_error: 0.1978
#
# Epoch 00106: val_loss did not improve from 0.03550
# Epoch 107/1000
# 45/45 [==============================] - 14s 316ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.1693 - val_mean_absolute_error: 0.1693
#
# Epoch 00107: val_loss did not improve from 0.03550
# Epoch 108/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1819 - val_mean_absolute_error: 0.1819
#
# Epoch 00108: val_loss did not improve from 0.03550
# Epoch 109/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.1842 - val_mean_absolute_error: 0.1842
#
# Epoch 00109: val_loss did not improve from 0.03550
# Epoch 110/1000
# 45/45 [==============================] - 14s 314ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1876 - val_mean_absolute_error: 0.1876
#
# Epoch 00110: val_loss did not improve from 0.03550
# Epoch 111/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.1948 - val_mean_absolute_error: 0.1948
#
# Epoch 00111: val_loss did not improve from 0.03550
# Epoch 112/1000
# 45/45 [==============================] - 15s 327ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.2022 - val_mean_absolute_error: 0.2022
#
# Epoch 00112: val_loss did not improve from 0.03550
# Epoch 113/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.1992 - val_mean_absolute_error: 0.1992
#
# Epoch 00113: val_loss did not improve from 0.03550
# Epoch 114/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.2159 - val_mean_absolute_error: 0.2159
#
# Epoch 00114: val_loss did not improve from 0.03550
# Epoch 115/1000
# 45/45 [==============================] - 14s 321ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.2065 - val_mean_absolute_error: 0.2065
#
# Epoch 00115: val_loss did not improve from 0.03550
# Epoch 116/1000
# 45/45 [==============================] - 14s 309ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.2036 - val_mean_absolute_error: 0.2036
#
# Epoch 00116: val_loss did not improve from 0.03550
# Epoch 117/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.2136 - val_mean_absolute_error: 0.2136
#
# Epoch 00117: val_loss did not improve from 0.03550
# Epoch 118/1000
# 45/45 [==============================] - 14s 315ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.1775 - val_mean_absolute_error: 0.1775
#
# Epoch 00118: val_loss did not improve from 0.03550
# Epoch 119/1000
# 45/45 [==============================] - 14s 314ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1841 - val_mean_absolute_error: 0.1841
#
# Epoch 00119: val_loss did not improve from 0.03550
# Epoch 120/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.2011 - val_mean_absolute_error: 0.2011
#
# Epoch 00120: val_loss did not improve from 0.03550
# Epoch 121/1000
# 45/45 [==============================] - 14s 315ms/step - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.2032 - val_mean_absolute_error: 0.2032
#
# Epoch 00121: val_loss did not improve from 0.03550
# Epoch 122/1000
# 45/45 [==============================] - 14s 319ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.2208 - val_mean_absolute_error: 0.2208
#
# Epoch 00122: val_loss did not improve from 0.03550
# Epoch 123/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.2148 - val_mean_absolute_error: 0.2148
#
# Epoch 00123: val_loss did not improve from 0.03550
# Epoch 124/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2166 - val_mean_absolute_error: 0.2166
#
# Epoch 00124: val_loss did not improve from 0.03550
# Epoch 125/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.2083 - val_mean_absolute_error: 0.2083
#
# Epoch 00125: val_loss did not improve from 0.03550
# Epoch 126/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.1981 - val_mean_absolute_error: 0.1981
#
# Epoch 00126: val_loss did not improve from 0.03550
# Epoch 127/1000
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.2051 - val_mean_absolute_error: 0.2051
#
# Epoch 00127: val_loss did not improve from 0.03550
# Epoch 128/1000
# 45/45 [==============================] - 14s 313ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.2158 - val_mean_absolute_error: 0.2158
#
# Epoch 00128: val_loss did not improve from 0.03550
# Epoch 129/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.2184 - val_mean_absolute_error: 0.2184
#
# Epoch 00129: val_loss did not improve from 0.03550
# Epoch 130/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.1749 - val_mean_absolute_error: 0.1749
#
# Epoch 00130: val_loss did not improve from 0.03550
# Epoch 131/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1971 - val_mean_absolute_error: 0.1971
#
# Epoch 00131: val_loss did not improve from 0.03550
# Epoch 132/1000
# 45/45 [==============================] - 14s 318ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2024 - val_mean_absolute_error: 0.2024
#
# Epoch 00132: val_loss did not improve from 0.03550
# Epoch 133/1000
# 45/45 [==============================] - 14s 315ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.2417 - val_mean_absolute_error: 0.2417
#
# Epoch 00133: val_loss did not improve from 0.03550
# Epoch 134/1000
# 45/45 [==============================] - 14s 311ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2056 - val_mean_absolute_error: 0.2056
#
# Epoch 00134: val_loss did not improve from 0.03550
# Epoch 135/1000
# 45/45 [==============================] - 14s 312ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.2163 - val_mean_absolute_error: 0.2163
#
# Epoch 00135: val_loss did not improve from 0.03550
# Epoch 136/1000
# 45/45 [==============================] - 14s 313ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1867 - val_mean_absolute_error: 0.1867
#
# Epoch 00136: val_loss did not improve from 0.03550
# Epoch 137/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.2088 - val_mean_absolute_error: 0.2088
#
# Epoch 00137: val_loss did not improve from 0.03550
# Epoch 138/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1948 - val_mean_absolute_error: 0.1948
#
# Epoch 00138: val_loss did not improve from 0.03550
# Epoch 139/1000
# 45/45 [==============================] - 14s 320ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.1810 - val_mean_absolute_error: 0.1810
#
# Epoch 00139: val_loss did not improve from 0.03550
# Epoch 140/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.1834 - val_mean_absolute_error: 0.1834
#
# Epoch 00140: val_loss did not improve from 0.03550
# Epoch 141/1000
# 45/45 [==============================] - 13s 296ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.1961 - val_mean_absolute_error: 0.1961
#
# Epoch 00141: val_loss did not improve from 0.03550
# Epoch 142/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.2030 - val_mean_absolute_error: 0.2030
#
# Epoch 00142: val_loss did not improve from 0.03550
# Epoch 143/1000
# 45/45 [==============================] - 14s 318ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1897 - val_mean_absolute_error: 0.1897
#
# Epoch 00143: val_loss did not improve from 0.03550
# Epoch 144/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1875 - val_mean_absolute_error: 0.1875
#
# Epoch 00144: val_loss did not improve from 0.03550
# Epoch 145/1000
# 45/45 [==============================] - 14s 310ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1678 - val_mean_absolute_error: 0.1678
#
# Epoch 00145: val_loss did not improve from 0.03550
# Epoch 146/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.2026 - val_mean_absolute_error: 0.2026
#
# Epoch 00146: val_loss did not improve from 0.03550
# Epoch 147/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1898 - val_mean_absolute_error: 0.1898
#
# Epoch 00147: val_loss did not improve from 0.03550
# Epoch 148/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.1884 - val_mean_absolute_error: 0.1884
#
# Epoch 00148: val_loss did not improve from 0.03550
# Epoch 149/1000
# 45/45 [==============================] - 14s 304ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1873 - val_mean_absolute_error: 0.1873
#
# Epoch 00149: val_loss did not improve from 0.03550
# Epoch 150/1000
# 45/45 [==============================] - 13s 291ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1793 - val_mean_absolute_error: 0.1793
#
# Epoch 00150: val_loss did not improve from 0.03550
# Epoch 151/1000
# 45/45 [==============================] - 14s 312ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1760 - val_mean_absolute_error: 0.1760
#
# Epoch 00151: val_loss did not improve from 0.03550
# Epoch 152/1000
# 45/45 [==============================] - 14s 301ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1705 - val_mean_absolute_error: 0.1705
#
# Epoch 00152: val_loss did not improve from 0.03550
# Epoch 153/1000
# 45/45 [==============================] - 14s 304ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1996 - val_mean_absolute_error: 0.1996
#
# Epoch 00153: val_loss did not improve from 0.03550
# Epoch 154/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1827 - val_mean_absolute_error: 0.1827
#
# Epoch 00154: val_loss did not improve from 0.03550
# Epoch 155/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.2028 - val_mean_absolute_error: 0.2028
#
# Epoch 00155: val_loss did not improve from 0.03550
# Epoch 156/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.1885 - val_mean_absolute_error: 0.1885
#
# Epoch 00156: val_loss did not improve from 0.03550
# Epoch 157/1000
# 45/45 [==============================] - 14s 304ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.1943 - val_mean_absolute_error: 0.1943
#
# Epoch 00157: val_loss did not improve from 0.03550
# Epoch 158/1000
# 45/45 [==============================] - 13s 300ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1850 - val_mean_absolute_error: 0.1850
#
# Epoch 00158: val_loss did not improve from 0.03550
# Epoch 159/1000
# 45/45 [==============================] - 13s 292ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1870 - val_mean_absolute_error: 0.1870
#
# Epoch 00159: val_loss did not improve from 0.03550
# Epoch 160/1000
# 45/45 [==============================] - 14s 315ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1943 - val_mean_absolute_error: 0.1943
#
# Epoch 00160: val_loss did not improve from 0.03550
# Epoch 161/1000
# 45/45 [==============================] - 14s 312ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1929 - val_mean_absolute_error: 0.1929
#
# Epoch 00161: val_loss did not improve from 0.03550
# Epoch 162/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.2007 - val_mean_absolute_error: 0.2007
#
# Epoch 00162: val_loss did not improve from 0.03550
# Epoch 163/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.1938 - val_mean_absolute_error: 0.1938
#
# Epoch 00163: val_loss did not improve from 0.03550
# Epoch 164/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.1985 - val_mean_absolute_error: 0.1985
#
# Epoch 00164: val_loss did not improve from 0.03550
# Epoch 165/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1882 - val_mean_absolute_error: 0.1882
#
# Epoch 00165: val_loss did not improve from 0.03550
# Epoch 166/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1970 - val_mean_absolute_error: 0.1970
#
# Epoch 00166: val_loss did not improve from 0.03550
# Epoch 167/1000
# 45/45 [==============================] - 13s 295ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.2162 - val_mean_absolute_error: 0.2162
#
# Epoch 00167: val_loss did not improve from 0.03550
# Epoch 168/1000
# 45/45 [==============================] - 13s 298ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1956 - val_mean_absolute_error: 0.1956
#
# Epoch 00168: val_loss did not improve from 0.03550
# Epoch 169/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1958 - val_mean_absolute_error: 0.1958
#
# Epoch 00169: val_loss did not improve from 0.03550
# Epoch 170/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.2120 - val_mean_absolute_error: 0.2120
#
# Epoch 00170: val_loss did not improve from 0.03550
# Epoch 171/1000
# 45/45 [==============================] - 14s 304ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.2060 - val_mean_absolute_error: 0.2060
#
# Epoch 00171: val_loss did not improve from 0.03550
# Epoch 172/1000
# 45/45 [==============================] - 13s 300ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.1957 - val_mean_absolute_error: 0.1957
#
# Epoch 00172: val_loss did not improve from 0.03550
# Epoch 173/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.1926 - val_mean_absolute_error: 0.1926
#
# Epoch 00173: val_loss did not improve from 0.03550
# Epoch 174/1000
# 45/45 [==============================] - 14s 317ms/step - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.2000 - val_mean_absolute_error: 0.2000
#
# Epoch 00174: val_loss did not improve from 0.03550
# Epoch 175/1000
# 45/45 [==============================] - 14s 309ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.2029 - val_mean_absolute_error: 0.2029
#
# Epoch 00175: val_loss did not improve from 0.03550
# Epoch 176/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.1897 - val_mean_absolute_error: 0.1897
#
# Epoch 00176: val_loss did not improve from 0.03550
# Epoch 177/1000
# 45/45 [==============================] - 13s 300ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1971 - val_mean_absolute_error: 0.1971
#
# Epoch 00177: val_loss did not improve from 0.03550
# Epoch 178/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.2092 - val_mean_absolute_error: 0.2092
#
# Epoch 00178: val_loss did not improve from 0.03550
# Epoch 179/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.2034 - val_mean_absolute_error: 0.2034
#
# Epoch 00179: val_loss did not improve from 0.03550
# Epoch 180/1000
# 45/45 [==============================] - 13s 299ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2093 - val_mean_absolute_error: 0.2093
#
# Epoch 00180: val_loss did not improve from 0.03550
# Epoch 181/1000
# 45/45 [==============================] - 14s 301ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.2010 - val_mean_absolute_error: 0.2010
#
# Epoch 00181: val_loss did not improve from 0.03550
# Epoch 182/1000
# 45/45 [==============================] - 13s 301ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.1935 - val_mean_absolute_error: 0.1935
#
# Epoch 00182: val_loss did not improve from 0.03550
# Epoch 183/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1964 - val_mean_absolute_error: 0.1964
#
# Epoch 00183: val_loss did not improve from 0.03550
# Epoch 184/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2040 - val_mean_absolute_error: 0.2040
#
# Epoch 00184: val_loss did not improve from 0.03550
# Epoch 185/1000
# 45/45 [==============================] - 13s 293ms/step - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.2047 - val_mean_absolute_error: 0.2047
#
# Epoch 00185: val_loss did not improve from 0.03550
# Epoch 186/1000
# 45/45 [==============================] - 13s 295ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.2038 - val_mean_absolute_error: 0.2038
#
# Epoch 00186: val_loss did not improve from 0.03550
# Epoch 187/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.1938 - val_mean_absolute_error: 0.1938
#
# Epoch 00187: val_loss did not improve from 0.03550
# Epoch 188/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2019 - val_mean_absolute_error: 0.2019
#
# Epoch 00188: val_loss did not improve from 0.03550
# Epoch 189/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.2194 - val_mean_absolute_error: 0.2194
#
# Epoch 00189: val_loss did not improve from 0.03550
# Epoch 190/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.1960 - val_mean_absolute_error: 0.1960
#
# Epoch 00190: val_loss did not improve from 0.03550
# Epoch 191/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2023 - val_mean_absolute_error: 0.2023
#
# Epoch 00191: val_loss did not improve from 0.03550
# Epoch 192/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.2101 - val_mean_absolute_error: 0.2101
#
# Epoch 00192: val_loss did not improve from 0.03550
# Epoch 193/1000
# 45/45 [==============================] - 13s 298ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.2164 - val_mean_absolute_error: 0.2164
#
# Epoch 00193: val_loss did not improve from 0.03550
# Epoch 194/1000
# 45/45 [==============================] - 13s 284ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.2209 - val_mean_absolute_error: 0.2209
#
# Epoch 00194: val_loss did not improve from 0.03550
# Epoch 195/1000
# 45/45 [==============================] - 13s 293ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1987 - val_mean_absolute_error: 0.1987
#
# Epoch 00195: val_loss did not improve from 0.03550
# Epoch 196/1000
# 45/45 [==============================] - 13s 294ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.2174 - val_mean_absolute_error: 0.2174
#
# Epoch 00196: val_loss did not improve from 0.03550
# Epoch 197/1000
# 45/45 [==============================] - 13s 296ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1934 - val_mean_absolute_error: 0.1934
#
# Epoch 00197: val_loss did not improve from 0.03550
# Epoch 198/1000
# 45/45 [==============================] - 13s 295ms/step - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.2117 - val_mean_absolute_error: 0.2117
#
# Epoch 00198: val_loss did not improve from 0.03550
# Epoch 199/1000
# 45/45 [==============================] - 13s 295ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.2047 - val_mean_absolute_error: 0.2047
#
# Epoch 00199: val_loss did not improve from 0.03550
# Epoch 200/1000
# 45/45 [==============================] - 13s 298ms/step - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.2099 - val_mean_absolute_error: 0.2099
#
# Epoch 00200: val_loss did not improve from 0.03550
# Epoch 201/1000
# 45/45 [==============================] - 13s 297ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.2176 - val_mean_absolute_error: 0.2176
#
# Epoch 00201: val_loss did not improve from 0.03550
# Epoch 202/1000
# 45/45 [==============================] - 13s 295ms/step - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.2111 - val_mean_absolute_error: 0.2111
#
# Epoch 00202: val_loss did not improve from 0.03550
# Epoch 203/1000
# 45/45 [==============================] - 13s 288ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2210 - val_mean_absolute_error: 0.2210
#
# Epoch 00203: val_loss did not improve from 0.03550
# Epoch 204/1000
# 45/45 [==============================] - 13s 293ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.2037 - val_mean_absolute_error: 0.2037
#
# Epoch 00204: val_loss did not improve from 0.03550
# Epoch 205/1000
# 45/45 [==============================] - 13s 294ms/step - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.2089 - val_mean_absolute_error: 0.2089
#
# Epoch 00205: val_loss did not improve from 0.03550
# Epoch 206/1000
# 45/45 [==============================] - 13s 299ms/step - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.2024 - val_mean_absolute_error: 0.2024
#
# Epoch 00206: val_loss did not improve from 0.03550
# Epoch 207/1000
# 45/45 [==============================] - 13s 294ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.2047 - val_mean_absolute_error: 0.2047
#
# Epoch 00207: val_loss did not improve from 0.03550
# Epoch 208/1000
# 45/45 [==============================] - 13s 295ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.2032 - val_mean_absolute_error: 0.2032
#
# Epoch 00208: val_loss did not improve from 0.03550
# Epoch 209/1000
# 45/45 [==============================] - 13s 295ms/step - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.2068 - val_mean_absolute_error: 0.2068
#
# Epoch 00209: val_loss did not improve from 0.03550
# Epoch 210/1000
# 45/45 [==============================] - 14s 311ms/step - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.2024 - val_mean_absolute_error: 0.2024
#
# Epoch 00210: val_loss did not improve from 0.03550
# Epoch 211/1000
# 45/45 [==============================] - 13s 299ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.1968 - val_mean_absolute_error: 0.1968
#
# Epoch 00211: val_loss did not improve from 0.03550
# Epoch 212/1000
# 45/45 [==============================] - 13s 294ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.1981 - val_mean_absolute_error: 0.1981
#
# Epoch 00212: val_loss did not improve from 0.03550
# Epoch 213/1000
# 45/45 [==============================] - 13s 290ms/step - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.2017 - val_mean_absolute_error: 0.2017
#
# Epoch 00213: val_loss did not improve from 0.03550
# Epoch 214/1000
# 45/45 [==============================] - 13s 299ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2062 - val_mean_absolute_error: 0.2062
#
# Epoch 00214: val_loss did not improve from 0.03550
# Epoch 215/1000
# 45/45 [==============================] - 13s 299ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2087 - val_mean_absolute_error: 0.2087
#
# Epoch 00215: val_loss did not improve from 0.03550
# Epoch 216/1000
# 45/45 [==============================] - 13s 298ms/step - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.2215 - val_mean_absolute_error: 0.2215
#
# ...
#
# Epoch 00928: val_loss did not improve from 0.03550
# Epoch 929/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - val_loss: 0.2543 - val_mean_absolute_error: 0.2543
#
# Epoch 00929: val_loss did not improve from 0.03550
# Epoch 930/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2547 - val_mean_absolute_error: 0.2547
#
# Epoch 00930: val_loss did not improve from 0.03550
# Epoch 931/1000
# 45/45 [==============================] - 14s 304ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.2535 - val_mean_absolute_error: 0.2535
#
# Epoch 00931: val_loss did not improve from 0.03550
# Epoch 932/1000
# 45/45 [==============================] - 13s 297ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2517 - val_mean_absolute_error: 0.2517
#
# Epoch 00932: val_loss did not improve from 0.03550
# Epoch 933/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2556 - val_mean_absolute_error: 0.2556
#
# Epoch 00933: val_loss did not improve from 0.03550
# Epoch 934/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0057 - mean_absolute_error: 0.0057 - val_loss: 0.2525 - val_mean_absolute_error: 0.2525
#
# Epoch 00934: val_loss did not improve from 0.03550
# Epoch 935/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2541 - val_mean_absolute_error: 0.2541
#
# Epoch 00935: val_loss did not improve from 0.03550
# Epoch 936/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2528 - val_mean_absolute_error: 0.2528
#
# Epoch 00936: val_loss did not improve from 0.03550
# Epoch 937/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - val_loss: 0.2551 - val_mean_absolute_error: 0.2551
#
# Epoch 00937: val_loss did not improve from 0.03550
# Epoch 938/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2490 - val_mean_absolute_error: 0.2490
#
# Epoch 00938: val_loss did not improve from 0.03550
# Epoch 939/1000
# 45/45 [==============================] - 14s 311ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - val_loss: 0.2542 - val_mean_absolute_error: 0.2542
#
# Epoch 00939: val_loss did not improve from 0.03550
# Epoch 940/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2516 - val_mean_absolute_error: 0.2516
#
# Epoch 00940: val_loss did not improve from 0.03550
# Epoch 941/1000
# 45/45 [==============================] - 13s 298ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2539 - val_mean_absolute_error: 0.2539
#
# Epoch 00941: val_loss did not improve from 0.03550
# Epoch 942/1000
# 45/45 [==============================] - 14s 304ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2572 - val_mean_absolute_error: 0.2572
#
# Epoch 00942: val_loss did not improve from 0.03550
# Epoch 943/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2576 - val_mean_absolute_error: 0.2576
#
# Epoch 00943: val_loss did not improve from 0.03550
# Epoch 944/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2591 - val_mean_absolute_error: 0.2591
#
# Epoch 00944: val_loss did not improve from 0.03550
# Epoch 945/1000
# 45/45 [==============================] - 14s 311ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - val_loss: 0.2476 - val_mean_absolute_error: 0.2476
#
# Epoch 00945: val_loss did not improve from 0.03550
# Epoch 946/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - val_loss: 0.2543 - val_mean_absolute_error: 0.2543
#
# Epoch 00946: val_loss did not improve from 0.03550
# Epoch 947/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0056 - mean_absolute_error: 0.0056 - val_loss: 0.2596 - val_mean_absolute_error: 0.2596
#
# Epoch 00947: val_loss did not improve from 0.03550
# Epoch 948/1000
# 45/45 [==============================] - 14s 311ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2585 - val_mean_absolute_error: 0.2585
#
# Epoch 00948: val_loss did not improve from 0.03550
# Epoch 949/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2597 - val_mean_absolute_error: 0.2597
#
# Epoch 00949: val_loss did not improve from 0.03550
# Epoch 950/1000
# 45/45 [==============================] - 13s 294ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - val_loss: 0.2519 - val_mean_absolute_error: 0.2519
#
# Epoch 00950: val_loss did not improve from 0.03550
# Epoch 951/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - val_loss: 0.2532 - val_mean_absolute_error: 0.2532
#
# Epoch 00951: val_loss did not improve from 0.03550
# Epoch 952/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2530 - val_mean_absolute_error: 0.2530
#
# Epoch 00952: val_loss did not improve from 0.03550
# Epoch 953/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2637 - val_mean_absolute_error: 0.2637
#
# Epoch 00953: val_loss did not improve from 0.03550
# Epoch 954/1000
# 45/45 [==============================] - 14s 309ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2533 - val_mean_absolute_error: 0.2533
#
# Epoch 00954: val_loss did not improve from 0.03550
# Epoch 955/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - val_loss: 0.2568 - val_mean_absolute_error: 0.2568
#
# Epoch 00955: val_loss did not improve from 0.03550
# Epoch 956/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2498 - val_mean_absolute_error: 0.2498
#
# Epoch 00956: val_loss did not improve from 0.03550
# Epoch 957/1000
# 45/45 [==============================] - 14s 310ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.2540 - val_mean_absolute_error: 0.2540
#
# Epoch 00957: val_loss did not improve from 0.03550
# Epoch 958/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2565 - val_mean_absolute_error: 0.2565
#
# Epoch 00958: val_loss did not improve from 0.03550
# Epoch 959/1000
# 45/45 [==============================] - 13s 297ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.2487 - val_mean_absolute_error: 0.2487
#
# Epoch 00959: val_loss did not improve from 0.03550
# Epoch 960/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - val_loss: 0.2562 - val_mean_absolute_error: 0.2562
#
# Epoch 00960: val_loss did not improve from 0.03550
# Epoch 961/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2563 - val_mean_absolute_error: 0.2563
#
# Epoch 00961: val_loss did not improve from 0.03550
# Epoch 962/1000
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - val_loss: 0.2542 - val_mean_absolute_error: 0.2542
#
# Epoch 00962: val_loss did not improve from 0.03550
# Epoch 963/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2533 - val_mean_absolute_error: 0.2533
#
# Epoch 00963: val_loss did not improve from 0.03550
# Epoch 964/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.2518 - val_mean_absolute_error: 0.2518
#
# Epoch 00964: val_loss did not improve from 0.03550
# Epoch 965/1000
# 45/45 [==============================] - 14s 301ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.2546 - val_mean_absolute_error: 0.2546
#
# Epoch 00965: val_loss did not improve from 0.03550
# Epoch 966/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0058 - mean_absolute_error: 0.0058 - val_loss: 0.2721 - val_mean_absolute_error: 0.2721
#
# Epoch 00966: val_loss did not improve from 0.03550
# Epoch 967/1000
# 45/45 [==============================] - 14s 312ms/step - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.2547 - val_mean_absolute_error: 0.2547
#
# Epoch 00967: val_loss did not improve from 0.03550
# Epoch 968/1000
# 45/45 [==============================] - 13s 295ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - val_loss: 0.2578 - val_mean_absolute_error: 0.2578
#
# Epoch 00968: val_loss did not improve from 0.03550
# Epoch 969/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.2571 - val_mean_absolute_error: 0.2571
#
# Epoch 00969: val_loss did not improve from 0.03550
# Epoch 970/1000
# 45/45 [==============================] - 14s 309ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2614 - val_mean_absolute_error: 0.2614
#
# Epoch 00970: val_loss did not improve from 0.03550
# Epoch 971/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2488 - val_mean_absolute_error: 0.2488
#
# Epoch 00971: val_loss did not improve from 0.03550
# Epoch 972/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2536 - val_mean_absolute_error: 0.2536
#
# Epoch 00972: val_loss did not improve from 0.03550
# Epoch 973/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.2560 - val_mean_absolute_error: 0.2560
#
# Epoch 00973: val_loss did not improve from 0.03550
# Epoch 974/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - val_loss: 0.2587 - val_mean_absolute_error: 0.2587
#
# Epoch 00974: val_loss did not improve from 0.03550
# Epoch 975/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2531 - val_mean_absolute_error: 0.2531
#
# Epoch 00975: val_loss did not improve from 0.03550
# Epoch 976/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.2581 - val_mean_absolute_error: 0.2581
#
# Epoch 00976: val_loss did not improve from 0.03550
# Epoch 977/1000
# 45/45 [==============================] - 13s 297ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2578 - val_mean_absolute_error: 0.2578
#
# Epoch 00977: val_loss did not improve from 0.03550
# Epoch 978/1000
# 45/45 [==============================] - 14s 304ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2602 - val_mean_absolute_error: 0.2602
#
# Epoch 00978: val_loss did not improve from 0.03550
# Epoch 979/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2658 - val_mean_absolute_error: 0.2658
#
# Epoch 00979: val_loss did not improve from 0.03550
# Epoch 980/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2597 - val_mean_absolute_error: 0.2597
#
# Epoch 00980: val_loss did not improve from 0.03550
# Epoch 981/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2592 - val_mean_absolute_error: 0.2592
#
# Epoch 00981: val_loss did not improve from 0.03550
# Epoch 982/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - val_loss: 0.2559 - val_mean_absolute_error: 0.2559
#
# Epoch 00982: val_loss did not improve from 0.03550
# Epoch 983/1000
# 45/45 [==============================] - 14s 309ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - val_loss: 0.2609 - val_mean_absolute_error: 0.2609
#
# Epoch 00983: val_loss did not improve from 0.03550
# Epoch 984/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2595 - val_mean_absolute_error: 0.2595
#
# Epoch 00984: val_loss did not improve from 0.03550
# Epoch 985/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.2616 - val_mean_absolute_error: 0.2616
#
# Epoch 00985: val_loss did not improve from 0.03550
# Epoch 986/1000
# 45/45 [==============================] - 13s 296ms/step - loss: 0.0048 - mean_absolute_error: 0.0048 - val_loss: 0.2661 - val_mean_absolute_error: 0.2661
#
# Epoch 00986: val_loss did not improve from 0.03550
# Epoch 987/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - val_loss: 0.2596 - val_mean_absolute_error: 0.2596
#
# Epoch 00987: val_loss did not improve from 0.03550
# Epoch 988/1000
# 45/45 [==============================] - 14s 303ms/step - loss: 0.0055 - mean_absolute_error: 0.0055 - val_loss: 0.2629 - val_mean_absolute_error: 0.2629
#
# Epoch 00988: val_loss did not improve from 0.03550
# Epoch 989/1000
# 45/45 [==============================] - 14s 308ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - val_loss: 0.2574 - val_mean_absolute_error: 0.2574
#
# Epoch 00989: val_loss did not improve from 0.03550
# Epoch 990/1000
# 45/45 [==============================] - 14s 306ms/step - loss: 0.0049 - mean_absolute_error: 0.0049 - val_loss: 0.2528 - val_mean_absolute_error: 0.2528
#
# Epoch 00990: val_loss did not improve from 0.03550
# Epoch 991/1000
# 45/45 [==============================] - 14s 309ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - val_loss: 0.2600 - val_mean_absolute_error: 0.2600
#
# Epoch 00991: val_loss did not improve from 0.03550
# Epoch 992/1000
# 45/45 [==============================] - 14s 313ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - val_loss: 0.2604 - val_mean_absolute_error: 0.2604
#
# Epoch 00992: val_loss did not improve from 0.03550
# Epoch 993/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2604 - val_mean_absolute_error: 0.2604
#
# Epoch 00993: val_loss did not improve from 0.03550
# Epoch 994/1000
# 45/45 [==============================] - 14s 301ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2574 - val_mean_absolute_error: 0.2574
#
# Epoch 00994: val_loss did not improve from 0.03550
# Epoch 995/1000
# 45/45 [==============================] - 13s 298ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - val_loss: 0.2503 - val_mean_absolute_error: 0.2503
#
# Epoch 00995: val_loss did not improve from 0.03550
# Epoch 996/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0050 - mean_absolute_error: 0.0050 - val_loss: 0.2597 - val_mean_absolute_error: 0.2597
#
# Epoch 00996: val_loss did not improve from 0.03550
# Epoch 997/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2567 - val_mean_absolute_error: 0.2567
#
# Epoch 00997: val_loss did not improve from 0.03550
# Epoch 998/1000
# 45/45 [==============================] - 14s 305ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - val_loss: 0.2492 - val_mean_absolute_error: 0.2492
#
# Epoch 00998: val_loss did not improve from 0.03550
# Epoch 999/1000
# 45/45 [==============================] - 14s 301ms/step - loss: 0.0051 - mean_absolute_error: 0.0051 - val_loss: 0.2531 - val_mean_absolute_error: 0.2531
#
# Epoch 00999: val_loss did not improve from 0.03550
# Epoch 1000/1000
# 45/45 [==============================] - 14s 307ms/step - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.2654 - val_mean_absolute_error: 0.2654
#
# Epoch 01000: val_loss did not improve from 0.03550

# %%
#Save the Model for import later

# Save model as JSON
aaplmodel_15day = model.to_json()

file_path = Path("aaplmodel_15day.json")
with open(file_path, "w") as json_file:
    json_file.write(aaplmodel_15day)

# Save weights
aaplmodel_15day_file_path = ("aaplmodel_15day.h5")
model.save_weights("aaplmodel_15day.h5")

# %%
import matplotlib.pyplot as plt

def plot_graph(test_df):
    """
    This function plots true close price along with predicted close price
    with blue and red colors respectively
    """
    plt.plot(test_df[f'true_adjclose_{LOOKUP_STEP}'], c='b')
    plt.plot(test_df[f'adjclose_{LOOKUP_STEP}'], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()

# %%
def get_final_df(model, data):
    """
    This function takes the `model` and `data` dict to 
    construct a final dataframe that includes the features along 
    with true and predicted prices of the testing dataset
    """
    # if predicted future price is higher than the current, 
    # then calculate the true future price minus the current price, to get the buy profit
    buy_profit  = lambda current, true_future, pred_future: true_future - current if pred_future > current else 0
    # if the predicted future price is lower than the current price,
    # then subtract the true future price from the current price
    sell_profit = lambda current, true_future, pred_future: current - true_future if pred_future < current else 0
    X_test = data["X_test"]
    y_test = data["y_test"]
    # perform prediction and get prices
    y_pred = model.predict(X_test)
    if SCALE:
        y_test = np.squeeze(data["column_scaler"]["Adj Close"].inverse_transform(np.expand_dims(y_test, axis=0)))
        y_pred = np.squeeze(data["column_scaler"]["Adj Close"].inverse_transform(y_pred))
    test_df = data["test_df"]
    # add predicted future prices to the dataframe
    test_df[f"adjclose_{LOOKUP_STEP}"] = y_pred
    # add true future prices to the dataframe
    test_df[f"true_adjclose_{LOOKUP_STEP}"] = y_test
    # sort the dataframe by date
    test_df.sort_index(inplace=True)
    final_df = test_df
    # add the buy profit column
    final_df["buy_profit"] = list(map(buy_profit, 
                                    final_df["Adj Close"], 
                                    final_df[f"adjclose_{LOOKUP_STEP}"], 
                                    final_df[f"true_adjclose_{LOOKUP_STEP}"])
                                    # since we don't have profit for last sequence, add 0's
                                    )
    # add the sell profit column
    final_df["sell_profit"] = list(map(sell_profit, 
                                    final_df["Adj Close"], 
                                    final_df[f"adjclose_{LOOKUP_STEP}"], 
                                    final_df[f"true_adjclose_{LOOKUP_STEP}"])
                                    # since we don't have profit for last sequence, add 0's
                                    )
    return final_df

# %%
def predict(model, data):
    # retrieve the last sequence from data
    last_sequence = data["last_sequence"][-N_STEPS:]
    # expand dimension
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    if SCALE:
        predicted_price = data["column_scaler"]["Adj Close"].inverse_transform(prediction)[0][0]
    else:
        predicted_price = prediction[0][0]# load optimal model weights from results folder
    model_path = os.path.join("results", model_name) + ".h5"
    model.load_weights(model_path)
    return predicted_price

# %%
# load optimal model weights from results folder
model_path = os.path.join("results", model_name) + ".h5"
model.load_weights(model_path)

# %%
# evaluate the model
loss, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
if SCALE:
    mean_absolute_error = data["column_scaler"]["Adj Close"].inverse_transform([[mae]])[0][0]
else:
    mean_absolute_error = mae

# %%
# predict the future price
final_df = get_final_df(model, data)

# predict the future price
future_price = predict(model, data)

final_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-02   43.807499   44.437500   43.450001   44.142502   42.588531
# 2018-05-03   43.970001   44.375000   43.610001   44.222500   42.665707
# 2018-05-04   44.562500   46.062500   44.542500   45.957500   44.339626
# 2018-05-07   46.294998   46.917500   46.187500   46.290001   44.660423
# 2018-05-08   46.247501   46.555000   45.917500   46.512501   44.875103
# ...                ...         ...         ...         ...         ...
# 2021-03-03  124.809998  125.709999  121.839996  122.059998  122.059998
# 2021-03-04  121.750000  123.599998  118.620003  120.129997  120.129997
# 2021-03-05  120.980003  121.940002  117.570000  121.419998  121.419998
# 2021-03-08  120.930000  121.000000  116.209999  116.360001  116.360001
# 2021-03-09  119.029999  122.059998  118.790001  121.089996  121.089996
#
#                Volume  adjclose_15  true_adjclose_15  buy_profit  sell_profit
# Date
# 2018-05-02  266157600    40.948448         45.607460   -1.640083     0.000000
# 2018-05-03  136272800    41.508503         45.556606   -1.157204     0.000000
# 2018-05-04  224805200    42.132786         45.660728   -2.206841     0.000000
# 2018-05-07  169805600    42.901199         45.496067   -1.759224     0.000000
# 2018-05-08  113611200    43.587788         45.399216   -1.287315     0.000000
# ...               ...          ...               ...         ...          ...
# 2021-03-03  112430400   131.390198        120.089996    0.000000    -9.330200
# 2021-03-04  177275300   131.058365        120.589996   10.928368     0.000000
# 2021-03-05  153590400   130.831451        121.209999    0.000000    -9.411453
# 2021-03-08  153918600   130.471863        121.389999   14.111862     0.000000
# 2021-03-09  129159600   130.427551        119.900002    0.000000    -9.337555
#
# [718 rows x 10 columns]

# %%
# we calculate the accuracy by counting the number of positive profits
accuracy_score = (len(final_df[final_df['sell_profit'] > 0]) + len(final_df[final_df['buy_profit'] > 0])) / len(final_df)
# calculating total buy & sell profit
total_buy_profit  = final_df["buy_profit"].sum()
total_sell_profit = final_df["sell_profit"].sum()
# total profit by adding sell & buy together
total_profit = total_buy_profit + total_sell_profit
# dividing total profit by number of testing samples (number of trades)
profit_per_trade = total_profit / len(final_df)

# %%
# printing metrics
print(f"Future price after {LOOKUP_STEP} days is {future_price:.2f}$")
print(f"{LOSS} loss:", loss)
print("Mean Absolute Error:", mean_absolute_error)
print("Accuracy score:", accuracy_score)
print("Total buy profit:", total_buy_profit)
print("Total sell profit:", total_sell_profit)
print("Total profit:", total_profit)
print("Profit per trade:", profit_per_trade)
# Out:
# Future price after 15 days is 130.22$
# mae loss: 0.035497669130563736
# Mean Absolute Error: 7.247067798584415
# Accuracy score: 0.6350974930362117
# Total buy profit: 1648.8446311950684
# Total sell profit: -670.4252738952637
# Total profit: 978.4193572998047
# Profit per trade: 1.362701054735104

# %%
# printing metrics
print(f"This model predicts the Future price after {LOOKUP_STEP} days will be {future_price:.2f}$")
# plot true/pred prices graph
plot_graph(final_df)
# Out:
# This model predicts the Future price after 15 days will be 130.22$
